# %% [markdown]
# https://ai.google.dev/gemini-api/tutorials/document_search

# %% [markdown]
# https://cloud.google.com/vertex-ai/generative-ai/docs/model-reference/gemini

# %%
# %pip install rapidfuzz
# Out:
# Requirement already satisfied: rapidfuzz in /opt/conda/lib/python3.10/site-packages (3.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from google.cloud import bigquery
import re
import json
from datetime import datetime
import numpy as np
import pandas as pd
from difflib import SequenceMatcher
from rapidfuzz import fuzz, process

# %%
def read_bq():
    client = bigquery.Client()
    
    query = f"""
        SELECT *
        FROM `intern-project-415606.Criminal_Dataset.criminal_data`
    """
    
    try:
        query_job = client.query(query)
        df = query_job.to_dataframe()
        return df
    except Exception as e:
        print(f"Error: {e}")

# %%
df = read_bq()
df.head()
# Out:
#                                             JLR_LINK TRANS_TYPE_OF_CASE  \
# 0  https://congbobanan.toaan.gov.vn/2ta827827t1cv...        採取行政處理措施的決定
# 1  https://congbobanan.toaan.gov.vn/2ta889668t1cv...                 刑事
# 2  https://congbobanan.toaan.gov.vn/2ta153804t1cv...                 刑事
# 3  https://congbobanan.toaan.gov.vn/2ta1126341t1c...                 刑事
# 4  https://congbobanan.toaan.gov.vn/2ta1066372t1c...                 刑事
#
#   TRANS_LEGAL_RELATIONSHIP                                           PDF_TEXT  \
# 0                放入強制性戒毒機構  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
# 1                 犯罪非法持有毒品  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
# 2                    盜竊財產罪  <Page:1>TOÀ ÁN NHÂN DÂN CỘNG HOÀ XÃ HỘI CHỦ NG...
# 3                 犯罪非法持有毒品  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
# 4                  欺詐佔有財產罪  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
#
#                                              EXTRACT     ID          NAME  \
# 0   Họ và tên: Nguyễn Văn C – Giới tính: Nam Sinh...  No_Id  Nguyễn Văn C
# 1   Họ và tên: Trần Ngọc T, sinh ngày 08/12/1993....  No_Id   Trần Ngọc T
# 2   Bùi Văn T, sinh ngày 09/12/1989 Tại: Xóm T – ...  No_Id     Bùi Văn T
# 3   Nguyễn Văn Đ, sinh ngày 04/8/1978 tại huyện H...  No_Id  Nguyễn Văn Đ
# 4   Cao Thị B, sinh ngày 01/01/1975, tại huyện C,...  No_Id     Cao Thị B
#
#    Year  Month  Day  GENDER                BIRTH
# 0  1994      1   25    Male  1994-01-25 00:00:00
# 1  1993     12    8    Male  1993-12-08 00:00:00
# 2  1989     12    9    Male  1989-12-09 00:00:00
# 3  1978      8    4    Male  1978-08-04 00:00:00
# 4  1975      1    1  Female  1975-01-01 00:00:00

# %%
a = df.loc[df['JLR_LINK'] == "https://congbobanan.toaan.gov.vn/2ta946636t1cvn/chi-tiet-ban-an", 'PDF_TEXT']
for b in a:
    print(b)
    break
# Out:
# <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM
# THÀNH PHỐ LẠNG SƠN Độc lập - Tự do - Hạnh phúc
# TỈNH LẠNG SƠN
# Bản án số: 28/2022/HS-ST
# Ngày 07-4-2022
# NHÂN DANH
# NƯỚC CỘNG HÒA XÃ HỘI CHỦ NGHĨA VIỆT NAM
# TÒA ÁN NHÂN DÂN THÀNH PHỐ LẠNG SƠN, TỈNH LẠNG SƠN
# - Thành phần Hội đồng xét xử sơ thẩm gồm có:
# Thẩm phán Chủ tọa phiên tòa: Bà Nguyễn Minh Huyền
# Các Hội thẩm nhân dân: Bà Ngô Thị Thục
# Bà Dương Thị Thu Thủy
# - Thư ký phiên tòa: Bà Hoàng Hồng Hạnh - Thư ký Tòa án nhân dân thành
# phố Lạng Sơn, tỉnh Lạng Sơn.
# - Đại diện Viện Kiểm sát nhân dân thành phố Lạng Sơn, tỉnh Lạng Sơn
# tham gia phiên tòa: Bà Lê Thị Khanh - Kiểm sát viên.
# Ngày 07 tháng 4 năm 2022 tại trụ sở Tòa án nhân dân thành phố Lạng Sơn,
# tỉnh Lạng Sơn, xét xử sơ thẩm công khai vụ án hình sự sơ thẩm thụ lý số:
# 18/2022/TLST-HS ngày 28 tháng 01 năm 2022 theo Quyết định đưa vụ án ra xét xử
# số: 29/2022/QĐXXST-HS ngày 17 tháng 3 năm 2022, Quyết định hoãn phiên tòa
# số 09/2022/HSST-QĐ ngày 29 tháng 3 năm 2022, đối với các bị cáo:
# 1. Nguyễn Kim P, (tên gọi khác: Không), sinh ngày 30/10/1968 tại tỉnh Lạng
# Sơn, nơi ĐKHKTT và chỗ ở: Số 18, N, phường C, thành phố L, tỉnh Lạng Sơn; nghề
# nghiệp: Không; trình độ văn hóa: 12/12; dân tộc: Kinh; giới tính: Nữ; tôn giáo:
# Không; quốc tịch: Việt Nam; con ông: Nguyễn Văn T, sinh năm 1937 và bà Ngô Thị
# V (đã chết); có chồng: Nguyễn Hùng C, sinh năm 1965 và 03 con, con lớn sinh năm
# 1989, con nhỏ sinh năm 2002; tiền án, tiền sự: Không; nhân thân: Chưa từng bị kết
# án, xử lý hành chính, xử lý kỷ luật; bị bắt tạm giam từ ngày 10/7/2021 đến ngày
# 13/8/2021 được thay thế bằng biện pháp bảo lĩnh cho đến nay. Có mặt.
# 2. Nguyễn Quỳnh A, (tên gọi khác: Không), sinh ngày 09/02/1981 tại tỉnh
# Lạng Sơn; nơi ĐKHKTT và chỗ ở: Số 16, N, phường C, thành phố L, tỉnh Lạng Sơn;
# nghề nghiệp: Lao động tự do; trình độ văn hóa: 08/12; dân tộc: Kinh; giới tính: Nữ ;
# tôn giáo: Không; quốc tịch: Việt Nam; con ông: Nguyễn Hùng D, sinh năm 1956 và
# bà Nguyễn Thị Bích T (đã chết); chồng: Chưa có; con: Có 02 con, con lớn sinh năm
# 2011, con nhỏ sinh năm 2018; tiền án: Không; tiền sự: Ngày 11/6/2021 Công an
# phường C, thành phố L ra Quyết định xử phạt vi phạm hành chính số 15/QĐ-XPHC
# (hành vi bán số đề); nhân thân: Chưa từng bị kết án; bị áp dụng biện pháp ngăn chặn
# cấm đi khỏi nơi cư trú từ ngày 10/7/2021 đến nay. Có mặt.<Page:2>3. Nguyễn Thu H, (tên gọi khác: Không), sinh ngày 19/01/1992 tại tỉnh Lạng
# Sơn (bị cáo là con đẻ của bị cáo Nguyễn Kim P); nơi ĐKHKTT và chỗ ở: Số 196,
# đường M, phường V, thành phố L, tỉnh Lạng Sơn; nghề nghiệp: Lao động tự do; trình
# độ văn hóa: 12/12; dân tộc: Kinh; giới tính: Nữ; tôn giáo: Không; quốc tịch: Việt
# Nam; con ông: Nguyễn Hùng C, sinh năm 1965 và bà Nguyễn Kim P, sinh năm 1968;
# có chồng: Vương Văn Đ, sinh năm 1989 và 02 con, con lớn sinh năm 2013, con nhỏ
# sinh năm 2019; tiền án, tiền sự: Không; nhân thân: Chưa từng bị kết án, xử lý hành
# chính, xử lý kỷ luật; bị áp dụng biện pháp ngăn chặn cấm đi khỏi nơi cư trú từ ngày
# 10/7/2021 đến nay. Có mặt.
# - Người có quyền lợi, nghĩa vụ liên quan đến vụ án: Ông Nguyễn Phương Đ,
# sinh năm 1970 và bà Trần Thị Lan P, sinh năm 1976; cùng địa chỉ: Số 28/2, đường
# C2, phường V, thành phố L, tỉnh Lạng Sơn. Đều vắng mặt.
# - Người làm chứng: Chị Nguyễn Lan A, bà Vũ Thị Hồng V, bà Vũ Thị T.
# Đều vắng mặt.
# NỘI DUNG VỤ ÁN:
# Theo các tài liệu có trong hồ sơ vụ án và diễn biến tại phiên tòa, nội dung vụ
# án được tóm tắt như sau:
# Hồi 18 giờ 30 phút, ngày 09/7/2021, Công an thành phố Lạng Sơn kiểm tra
# tại số nhà 18 N, phường C, thành phố Lạng Sơn thấy tại phòng khách tầng 01 có
# Nguyễn Kim P và Nguyễn Thu H đang sử dụng máy tính cầm tay Casio để tính số
# lô, số đề tư nhân. Nguyễn Kim P khai nhận, ngày 09/7/2021, sử dụng số điện thoại
# 0865.828.360 để nhắn tin mua bán số lô, số đề với Nguyễn Quỳnh A qua số điện
# thoại 0334.684.858.
# Quá trình điều tra, xác định: Nguyễn Kim P, Nguyễn Quỳnh A là thư ký
# nhận số lô, số đề dưới hình thức ghi trực tiếp hoặc qua điện thoại. Trước 18 giờ 15
# phút hàng ngày, Nguyễn Quỳnh A chuyển số lô, đề đã bán được trong ngày cho
# Nguyễn Kim P để hưởng % lợi nhuận; Nguyễn Thu H, Trần Thị Lan P chuyển số lô,
# đề đánh bạc cho Nguyễn Kim P. Căn cứ vào kết quả xổ số Miền Bắc mở thưởng
# hàng ngày, Nguyễn Kim P so sánh các số lô, đề nhận được để xem kết quả thắng
# thua rồi thanh toán cho Nguyễn Quỳnh A và người chơi.
# Việc chơi số lô, số đề giữa người chơi với các thư ký đều dựa trên kết quả xổ
# số kiến thiết miền bắc mở thưởng hàng ngày. Số tiền quy đổi 01 điểm đề, giải nhất,
# ba càng (ba số), xiên, lô tùy theo từng người chơi đã được thống nhất trước. Đề
# được tính theo hai số cuối của giải đặc biệt; giải nhất tính theo hai số cuối của giải
# nhất; ba càng (ba số) tính theo ba số cuối của giải đặc biệt đều tính 01 điểm = 1.000
# đồng, số tiền thư ký trả cho chủ đề là 01 điểm = 730 đồng. Lô tính theo hai số cuối
# của các giải thưởng, tính 01 điểm = 22.000 đồng, số tiền thư ký trả cho chủ đề là
# 21.800 đồng. Lô xiên gồm có lô xiên 2, lô xiên 3, lô xiên 4 là người mua cặp 2, 3
# hoặc 4 của số có 02 chữ số hàng chục và hàng đơn vị của các giải thưởng; tính 01
# điểm = 1.000 đồng, số tiền thư ký trả cho chủ đề là 01 điểm = 730 đồng.
# Trường hợp người chơi thắng thì 01 điểm đề hoặc 01 điểm giải nhất đều được
# 70.000 đồng; 01 điểm ba càng (ba số) được 400.000 đồng; 01 điểm xiên 2 được
# 10.000 đồng; 01 điểm xiên 3 được 40.000 đồng; 01 điểm xiên 4 được 100.000
# 2<Page:3>đồng; 01 điểm lô được 80.000 đồng. Sau khi có kết quả xổ số kiến thiết miền bắc,
# các đối tượng cũng như những người chơi thanh toán tiền thắng thua, hoa hồng %
# trực tiếp cho nhau vào ngày hôm sau.
# Căn cứ tài liệu chứng cứ, kết quả kiểm tra, kết quả xác định tiền đánh bạc, tiền
# thắng bạc. Xác định được Nguyễn Kim P, Nguyễn Quỳnh A, Nguyễn Thu H đã tổ
# chức đánh bạc, đánh bạc cụ thể như sau:
# 1. Hành vi đánh bạc của Nguyễn Thu H
# Ngày 08/7/2021, Nguyễn Thu H sử dụng số điện thoại 0983.275.345 nhắn tin
# vào số điện thoại 0865.828.360 của Nguyễn Kim P để mua 2000 điểm lô; 2000
# điểm số đề giải đặc biệt; 2000 điểm số đề giải nhất. Nguyễn Kim P tính Nguyễn
# Thu H với giá 22.000 đồng/1 điểm lô; 730 đồng/1 điểm đề giải nhất và đặc biệt.
# Xác định Nguyễn Thu H đánh bạc với Nguyễn Kim P số tiền là 46.920.000 đồng.
# Đối chiếu với kết quả xổ số Miền Bắc mở thưởng ngày 08/7/2021, Nguyễn Thu H
# không thắng bạc.
# 2. Hành vi tổ chức đánh bạc của Nguyễn Quỳnh A
# Nguyễn Quỳnh A làm đại lý bán vé số của Công ty TNHH MTV Xổ số kiến
# thiết Lạng Sơn. Trong quá trình bán vé số của công ty, Nguyễn Quỳnh A đã ghi số
# lô, đề của một số khách rồi chuyển cho Nguyễn Kim P để hưởng % chênh lệch.
# Nguyễn Quỳnh A tính với khách 01 điểm lô = 22.000 đồng; 01 điểm đề, giải nhất,
# lô xiên = 750 đồng. Khi chuyển cho Nguyễn Kim P, P tính 01 điểm lô = 21.800
# đồng; 01 điểm đề, giải nhất, lô xiên = 730 đồng.
# Ngày 09/7/2021, sau khi ghi các số lô, đề từ người chơi, Nguyễn Quỳnh A
# dùng điện thoại số 0334.684.858 nhắn tin vào số điện thoại 0865.828.360 của
# Nguyễn Kim P chuyển 216 điểm lô = 4.708.800 đồng; 8.506 điểm số đề, lô xiên =
# 6.209.380 đồng, tổng số tiền chuyển các số lô, đề là 10.918.180 đồng. Nguyễn
# Quỳnh A được hưởng phần trăm hoa hồng từ việc tổ chức đánh bạc là 213.320
# đồng. Đối chiếu kết quả xổ số miền bắc mở thưởng ngày 09/7/2021, xác định
# Nguyễn Quỳnh A thắng bạc 9.100.000 đồng.
# Xác định số tiền Nguyễn Quỳnh A đánh bạc với Nguyễn Kim P số tiền là
# 20.018.100 đồng. Sau khi có kết quả xổ số Miền Bắc ngày 09/7/2021, hành vi tổ
# chức đánh bạc của các bị cáo bị phát hiện nên giữa Nguyễn Kim P và Nguyễn
# Quỳnh A chưa tính tiền, thanh toán tiền.
# Kiểm tra điện thoại Samsung Galaxy A20S của Nguyễn Quỳnh A, phát hiện
# tin nhắn mua bán số lô, đề của số điện thoại 0333.452.512 ngày 09/7/2021 gồm 40
# điểm lô, tính 01 điểm = 22.000 đồng; 5.100 điểm đề, tính 01 điểm = 750 đồng.
# Tổng số tiền đánh bạc là 6.305.000 đồng. Đối chiếu kết quả xổ số Miền Bắc mở
# thưởng ngày 09/7/2021, người chơi này thắng 1.600.000 đồng. Nguyễn Quỳnh A
# khai nhận chỉ biết người chơi này tên Yến (không rõ họ, địa chỉ). Kết quả xác minh
# số điện thoại 0333.452.512 đăng ký chủ thuê bao tên Trần Thị P (sinh năm 1968,
# trú tại xã Tân Mỹ, huyện Văn Lãng, tỉnh Lạng Sơn), P trình bày không đăng ký và
# sử dụng số điện thoại nêu trên. Tin nhắn ngày 28/6/2021, số điện thoại
# 0385.513.126 nhắn tin mua số đề với Nguyễn Quỳnh A tổng số tiền 150.000 đồng,
# Quỳnh A không biết tên, tuổi, địa chỉ của người này. Kết quả xác minh số điện
# 3<Page:4>thoại 0385.513.126 đăng ký tên chủ thuê bao là Trương Thị Bình (sinh năm 1966,
# trú tại: số 12/15, ngõ 307, đường Lê Lợi, phường V, thành phố L), Bình trình bày
# số điện thoại trên là của bản thân nhưng không quen biết và không liên lạc gì với
# Nguyễn Quỳnh A. Do vậy không có căn cứ để xác định Trần Thị P và Trương Thị
# Bình có hành vi đánh bạc với Nguyễn Quỳnh A để xử lý trong vụ án này.
# 3. Hành vi tổ chức đánh bạc của Nguyễn Kim P
# Ngày 08/7/2021 Nguyễn Phương Đ và vợ là Trần Thị Lan P mua với Nguyễn
# Kim P 100 điểm lô (do P chuyển), Nguyễn Kim P tính 22.000đồng/1 điểm, tổng số
# tiền mua là 2.200.000 đồng, đối chiếu với kết quả xổ số Miền Bắc mở thưởng cùng
# ngày, xác định Đ, P không thắng bạc. Số tiền Nguyễn Phương Đ, Trần Thị Lan P
# đánh bạc với Nguyễn Kim P là 2.200.000 đồng. Cơ quan điều tra đã ra Quyết định
# xử phạt vi phạm hành chính đối với hành vi đánh bạc của Nguyễn Phương Đ và
# Trần Thị Lan P.
# Quá trình điều tra, Nguyễn Kim P khai nhận ngày 08/7/2021 và ngày
# 09/7/2021, Nguyễn Kim P mua các số lô, đề của Nguyễn Thu H, Trần Thị Lan P,
# Nguyễn Phương Đ, Nguyễn Quỳnh A tổng hợp lại, sau đó chuyển đi một phần và
# bản thân bị cáo còn tự đánh thêm số lô số đề rồi sử dụng số điện thoại
# 0865.828.360 nhắn tin bán cho Vũ Thị Hồng V (sinh năm 1971, trú tại số 15, Phai
# Luông 5, phường C, thành phố L) qua số điện thoại 0867.526.172 và Vũ Thị T
# (sinh năm 1974, trú tại: số 12, đường Nội Bộ, phường C, thành phố L) qua số điện
# thoại 0357.067.208 để hưởng phần trăm hoa hồng. Kết quả xác minh tại Tập đoàn
# Viễn thông di động Viettel, các số điện thoại 0867.526.172 và 0357.067.208 thời
# điểm các ngày 08/7/2021 và 09/7/2021 đều chưa đăng ký tên chủ thuê bao nên
# không có căn cứ chứng minh chủ sở hữu là V, T. Tại cơ quan điều tra, Vũ Thị T,
# Vũ Thị Hồng V không nhận được sử dụng các số điện thoại trên và không nhận có
# hành vi Tổ chức đánh bạc với Nguyễn Kim P. Tiến hành đối chất, kết quả Vũ Thị T,
# Vũ Thị Hồng V vẫn giữ nguyên lời khai như trên. Ngoài lời khai của P, không có
# tài liệu khác xác định T, V là người Tổ chức đánh bạc cho P nên chưa đủ căn cứ để
# xử lý.
# Nguyễn Kim P khai nhận nhờ Nguyễn Thu H chuyển khoản trả tiền cho Vũ
# Thị Hồng V qua số tài khoản 0510186948888, Ngân hàng MB Bank, chủ tài khoản
# Khúc Vĩ H số tiền 30.000.000 đồng. Cơ quan điều tra đã gửi công văn xác minh
# nhưng đến nay chưa nhận được kết quả trả lời của Ngân hàng MB Bank do đó
# không có căn cứ xác định số tiền trên là số tiền đánh bạc của các đối tượng.
# Ngày 09/7/2021, Nguyễn Lan A sử dụng số điện thoại 0363.863.138 nhắn tin
# mua số lô đề tư nhân với Nguyễn Kim P với tổng số tiền là 550.000 đồng. Nguyễn
# Kim P không nhận bán do vậy không xem xét xử lý đối với hành vi này của các đối
# tượng.
# Số điện thoại 0334.684.858 Nguyễn Quỳnh A sử dụng để nhắn tin chuyển số
# lô, đề cho Nguyễn Kim P, khi thấy P bị Cơ quan Công an bắt giữ nên đã vứt vào
# thùng rác trước nhà, Cơ quan điều tra tiến hành truy tìm nhưng không thấy.
# Tại bản Cáo trạng số 24/CT-VKS ngày 27 tháng 01 năm 2022, Viện kiểm sát
# nhân dân thành phố Lạng Sơn đã truy tố các bị cáo Nguyễn Kim P, Nguyễn Quỳnh
# A về tội Tổ chức đánh bạc theo quy định tại điểm c khoản 1 Điều 322 Bộ luật Hình sự;
# 4<Page:5>truy tố bị cáo Nguyễn Thu H về tội Đánh bạc theo quy định tại khoản 1 Điều 321 Bộ
# luật Hình sự.
# Tại phiên toà, các bị cáo đều khai nhận toàn bộ hành vi của mình như Cáo
# trạng đã truy tố.
# Tại phiên tòa, đại diện Viện kiểm sát nhân dân thành phố Lạng Sơn giữ
# nguyên quyết định truy tố và đề nghị Hội đồng xét xử tuyên bố: Bị cáo Nguyễn
# Kim P, Nguyễn Quỳnh A phạm tội “Tổ chức Đánh bạc” quy định tại điểm c khoản
# 1 Điều 322 Bộ luật hình sự. Bị cáo Nguyễn Thu H bị truy tố về tội Đánh bạc theo
# khoản 1 Điều 321 Bộ luật Hình sự. Đề nghị áp dụng điểm c khoản 1, 3 Điều 322;
# điểm s khoản 1, khoản 2 Điều 51, điểm g khoản 1 Điều 52, Điều 17, Điều 38, Điều
# 58 Bộ luật Hình sự: Xử phạt bị cáo Nguyễn Kim P từ 13-15 tháng tù, phạt bổ sung
# từ 20.000.000đ đến 25.000.000đ. Áp dụng điểm c khoản 1 Điều 322; điểm s khoản
# 1 Điều 51, Điều 17; Điều 38, Điều 58 Bộ luật Hình sự: Xử phạt bị cáo Nguyễn
# Quỳnh A từ 12 đến 14 tháng tù. Áp dụng khoản 1 Điều 321; Điểm i, s khoản 1
# Điều 51, Điều 65 Bộ luật Hình sự đối với bị cáo Nguyễn Thu H; xử phạt 13 đến 15
# tháng tù cho hưởng án treo, thời gian thử thách từ 26 đến 30 tháng. Về xử lý vật
# chứng, đề nghị áp dụng điểm a khoản 1 Điều 47 của Bộ luật Hình sự; điểm a, c
# khoản 2, điểm a khoản 3 Điều 106 của Bộ luật Tố tụng Hình sự: Tịch thu, hóa giá
# nộp ngân sách Nhà nước đối với 01 điện thoại di động nhãn hiệu Iphone 12promax,
# gắn 01 sim số 0983.275.345; 01 điện thoại Samsung Galaxy A20s, màu vàng; 01 điện
# thoại di động nhãn hiệu Iphone 6s màu vàng, gắn 01 sim số 0865.828.360; 02 máy
# tính cầm tay casio thu giữ của các bị cáo do đều liên quan đến hành vi phạm tội. Đối
# với 01 điện thoại di động nhãn hiệu Iphone 7plus màu đen, gắn 01 sim số
# 0857.087.892; 01 điện thoại Samsung Galaxy J2 Prime, màu vàng, gắn 01 sim số
# 0969225630 và 01 sim số 0327853635 không liên quan đến hành vi phạm tội cần
# phải cần trả lại cho các bị cáo. Đối với các sổ sách, hợp đồng, giấy tờ ghi con số,
# không có giá trị sử dụng nên tịch thu tiêu hủy. Các bị cáo phải chịu án phí theo quy
# định.
# Các bị cáo đều không có ý kiến tranh luận. Tại lời nói sau cùng cả 03 bị cáo
# đều xin được hưởng sự khoan hồng của pháp luật, xin giảm nhẹ hình phạt.
# NHẬN ĐỊNH CỦA TOÀ ÁN:
# Trên cơ sở nội dung vụ án, căn cứ vào các tài liệu trong hồ sơ vụ án đã được
# tranh tụng tại phiên tòa, Hội đồng xét xử nhận định như sau:
# [1] Về hành vi, quyết định tố tụng và về việc thu thập tài liệu, chứng cứ của
# Điều tra viên, Kiểm sát viên trong quá trình điều tra, truy tố đã thực hiện đúng về
# thẩm quyền, trình tự, thủ tục theo quy định của Bộ luật Tố tụng hình sự. Không có
# người nào có ý kiến hoặc khiếu nại về hành vi, quyết định tố tụng của Điều tra viên,
# Kiểm sát viên. Do đó, các hành vi, quyết định tố tụng và việc thu thập chứng cứ, tài
# liệu của Cơ quan tiến hành tố tụng, người tiến hành tố tụng đã thực hiện đều hợp
# pháp.
# [2] Tại phiên tòa, những người có quyền lợi, nghĩa vụ liên quan đều vắng
# mặt nhưng đều có đơn xin xét xử, giải quyết vắng mặt. Xét thấy, lời khai của
# những người vắng mặt tại cơ quan điều tra đã rõ, do đó việc vắng mặt không ảnh
# 5<Page:6>hưởng đến việc xét xử, căn cứ Điều 292 Bộ luật Tố tụng Hình sự, Hội đồng xét xử
# tiếp tục xét xử vụ án.
# [3] Quá trình điều tra và tại phiên tòa, lời khai của các bị cáo thống nhất với
# nhau, phù hợp với lời khai của người tham gia tố tụng khác, với các tài liệu, chứng
# cứ có trong hồ sơ vụ án đã được thẩm tra tại phiên tòa, do đó có đủ căn cứ xác
# định: Ngày 08/7/2021, Nguyễn Kim P tổ chức đánh bạc cho Nguyễn Thu H, Trần
# Thị Lan P và Nguyễn Phương Đ, tổng số tiền là 49.120.000 đồng. Ngày 09/7/2021,
# bị cáo Nguyễn Kim P tổ chức đánh bạc cho Nguyễn Quỳnh A với tổng số tiền là
# 20.018.180 đồng. Bị cáo Nguyễn Quỳnh A là thư ký ghi số lô, đề của các khách
# chơi sau đó tổng hợp chuyển cho Nguyễn Kim P với tổng số tiền 20.018.180 đồng
# để hưởng phần trăm lợi nhuận nên phải chịu trách nhiệm hình sự về tội Tổ chức
# đánh bạc với vai trò đồng phạm cùng Nguyễn Kim P. Ngày 08/7/2021, bị cáo
# Nguyễn Thu H đánh bạc dưới hình thức chơi số lô, đề với số tiền 46.920.000 đồng
# nên phải chịu trách nhiệm hình sự về tội Đánh bạc. Với hành vi nêu trên các bị cáo
# Nguyễn Kim P, Nguyễn Quỳnh A đã phạm vào tội Tổ chức đánh bạc quy định tại
# điểm c khoản 1 Điều 322 Bộ luật Hình sự. Bị cáo Nguyễn Thu H đã phạm vào tội
# Đánh bạc quy định tại khoản 1 Điều 321. Cáo trạng của Viện kiểm sát nhân dân
# thành phố Lạng Sơn truy tố các bị cáo là đúng người, đúng tội, đúng pháp luật.
# [4] Hành vi của các bị cáo gây ra là nguy hiểm cho xã hội, hành vi đó đã xâm
# phạm trực tiếp đến trật tự công cộng, gây mất trật tự trị an, ảnh hưởng xấu tới an
# ninh trật tự trên địa bàn, gây thiệt hại về kinh tế, là nguyên nhân phát sinh các loại
# tội phạm khác. Các bị cáo đều là người có đầy đủ năng lực trách nhiệm hình sự,
# nhận thức được việc tham gia đánh bạc là vi phạm pháp luật nhưng vẫn thực hiện
# với lỗi cố ý trực tiếp vì mục đích hám lợi cá nhân, mong muốn kiếm tiền một cách
# nhanh chóng, bất chấp pháp luật, do đó cần phải xử lý nghiêm minh để giáo dục và
# phòng ngừa chung.
# [5] Xét về nhân thân: Bị cáo Nguyễn Kim P và Nguyễn Thu H có nhân thân
# tốt, phạm tội lần đầu, chưa có tiền án, tiền sự. Bị cáo Nguyễn Quỳnh A đã có 01
# tiền sự về hành vi đánh bạc chưa được xóa.
# [6] Về tình tiết tăng nặng trách nhiệm hình sự: Bị cáo Nguyễn Quỳnh A,
# Nguyễn Thu H không có tình tiết tăng nặng. Bị cáo Nguyễn Kim P đã thực hiện
# hành vi phạm tội vào ngày 08/7/2021 và ngày 09/7/2021, số tiền phạm tội của các
# lần đều đủ yếu tố cấu thành tội phạm do đó bị cáo phải chịu tình tiết tăng nặng
# trách nhiệm hình sự phạm tội 02 lần trở lên theo quy định tại điểm g khoản 1 Điều
# 52 Bộ luật Hình sự .
# [7] Về tình tiết giảm nhẹ trách nhiệm hình sự: Quá trình điều tra, truy tố, xét
# xử, cả ba bị cáo đều khai báo thành khẩn, có thái độ ăn năn, hối cải nên các bị cáo
# được hưởng tình tiết giảm nhẹ quy định tại điểm s khoản 1 điều 51 Bộ luật Hình sự.
# Riêng bị cáo Nguyễn Kim P có ông ngoại là ông Ngô Văn Vàng được tặng thưởng
# huân chương kháng chiến hạng nhì, bị cáo tham gia tích cực ủng hộ quỹ phòng,
# chống covid 19 của địa phương nên được hưởng thêm 02 tình tiết giảm nhẹ được
# quy định tại khoản 2 Điều 51 Bộ luật Hình sự; bị cáo Nguyễn Thu H phạm tội lần
# đầu và thuộc trường hợp ít nghiêm trọng, tích cực tham gia công tác thiện nguyện
# 6<Page:7>nên được hưởng thêm tình tiết giảm nhẹ tại khoản điểm i khoản 1, 2 Điều 51 Bộ
# luật Hình sự.
# [8] Đánh giá vai trò đồng phạm của các bị cáo: Các bị cáo là đồng phạm có
# tính chất giản đơn. Bị cáo Nguyễn Quỳnh A nhận số lô, đề của khách chơi sau đó
# chuyển cho bị cáo Nguyễn Kim P để hưởng phần trăm lợi nhuận. Bị cáo Nguyễn
# Kim P sau khi nhận số lô, đề lại chuyển tiếp cho người khác để hưởng lợi nhuận và
# có dấu hiệu của hành vi đánh bạc tuy nhiên do không xác minh được các đối tượng
# này nên bị cáo phải chịu trách nhiệm với vai trò tổ chức đánh bạc chính trong vụ án
# nên phải chịu hình phạt nghiêm khắc hơn bị cáo Nguyễn Quỳnh A là đồng phạm
# giúp sức cho bị cáo về tội tổ chức đánh bạc. Bị cáo Nguyễn Thu H là người đánh
# bạc trực tiếp nên phải chịu trách nhiệm hình sự tương xứng với hành vi của bị cáo
# gây ra.
# [9] Từ phân tích nêu trên, xét thấy: Đối với bị cáo Nguyễn Kim P, tổng số
# tiền tổ chức đánh bạc hai lần là 69.138.180 đồng, bị cáo có 01 tình tiết giảm nhẹ tại
# khoản 1 và 02 tình tiết giảm nhẹ tại khoản 2 Điều 51 Bộ luật Hình sự, 01 tình tiết
# tăng nặng trách nhiệm hình sự, do đó cần phải cách ly bị cáo ra khỏi đời sống xã
# hội một thời gian để có tác dụng giáo dục, cải tạo, răn đe và phòng ngừa chung.
# Tuy nhiên xét về hoàn cảnh gia đình bị cáo Nguyễn Kim P hiện là lao động chính,
# chồng đang điều trị bệnh hiểm nghèo ung thư lưỡi, xét thấy xử phạt bị cáo trên mức
# khởi điểm của khung hình phạt đảm bảo tính răn đe đồng thời tạo điều kiện cho bị
# cáo sớm trở về chăm sóc gia đình và trở thành công dân có ích cho xã hội. Đối với
# bị cáo Nguyễn Quỳnh A số tiền phạm tội tổ chức đánh bạc là 20.018.180 đồng, vai
# trò giúp sức thứ yếu, có 01 tình tiết giảm nhẹ tại khoản 1 Điều 51 Bộ luật Hình sự,
# có 01 tiền sự về hành vi đánh bạc chưa được xóa do đó cần phải cách ly các bị cáo
# ra khỏi đời sống xã hội một thời gian, xét thấy bị cáo không có chồng, hiện đang
# nuôi hai con nhỏ, là lao động chính nên Hội đồng xét xử xét thấy cần xử mức hình
# phạt gần mức khởi điểm của khung hình phạt và thấp hơn hình phạt của bị cáo
# Nguyễn Kim P là phù hợp. Đối với bị cáo Nguyễn Thu H có 02 tình tiết giảm nhẹ
# quy định khoản 1 và 01 tình tiết giảm nhẹ tại khoản 2 Điều 51 Bộ luật Hình sự. Bị
# cáo nhân thân tốt, không có tiền án tiền sự, hiện đang nuôi con nhỏ dưới 03 tuổi, bị
# cáo có nơi cư trú cụ thể, rõ ràng, tại nơi cư trú có ý thức chấp hành đầy đủ mọi quy
# định của địa phương nơi cư trú và chính sách pháp luật của Nhà nước được chính
# quyền địa phương được xác nhận, nhận thấy không cần thiết xét xử bị cáo hình phạt
# tù giam mà cho bị cáo tự cải tạo tại địa phương cũng đảm bảo tính chất răn đe và
# thể hiện sự khoan hồng của Nhà nước.
# [10] Về hình phạt bổ sung: Đối với bị cáo Nguyễn Kim P phạm tội Tổ chức
# đánh bạc, mặc dù thực tế chưa được hưởng lợi nhuận nhưng là bị cáo có vai trò
# chính trong vụ án nên cần áp dụng thêm hình phạt bổ sung là hình phạt tiền. Các bị
# cáo khác không áp dụng hình phạt bổ sung. Xác nhận bị cáo Nguyễn Kim P đã nộp
# tiền phạt bổ sung 5.200.000 đồng tại Chi Cục thi hành án dân sự thành phố Lạng
# Sơn.
# [11] Về xử lý vật chứng: Đối với 01 điện thoại di động nhãn hiệu Iphone
# 12promax, gắn 01 sim số 0983.275.345; 01 điện thoại Samsung Galaxy A20s, màu
# vàng; 01 điện thoại di động nhãn hiệu Iphone 6s màu vàng, gắn 01 sim số
# 0865.828.360; 02 máy tính cầm tay casio thu giữ của các bị cáo do đều liên quan đến
# 7<Page:8>hành vi phạm tội nên cần tịch thu, hóa giá nộp ngân sách Nhà nước. Đối với 01 điện
# thoại di động nhãn hiệu Iphone 7plus màu đen, gắn 01 sim số 0857.087.892; 01 điện
# thoại Samsung Galaxy J2 Prime, màu vàng, gắn 01 sim số 0969225630 và 01 sim số
# 0327853635 không liên quan đến hành vi phạm tội cần phải cần trả lại cho các bị cáo
# Nguyễn Kim P và Nguyễn Quỳnh A. Đối với các sổ sách, hợp đồng, giấy tờ ghi con
# số, không có giá trị sử dụng nên tịch thu tiêu hủy.
# [12] Đối với những đối tượng liên quan, Cơ quan điều tra không xác minh,
# làm rõ được nên không có cơ sở để xem xét.
# [13] Xét lời luận tội của đại diện Viện kiểm sát tại phiên tòa cơ bản phù hợp
# với nhận định của Hội đồng xét xử nên được chấp nhận, tuy nhiên ý kiến nào chưa
# phù hợp với nhận định nêu trên của Hội đồng xét xử thì không được chấp nhận.
# [14] Về án phí: Các bị cáo bị kết án nên phải chịu án phí hình sự sơ thẩm;
# các bị cáo, người có quyền lợi nghĩa vụ liên quan có quyền kháng cáo bản án theo
# quy định của pháp luật.
# Vì các lẽ trên,
# QUYẾT ĐỊNH:
# 1. Về tội danh
# Tuyên bố:
# - Các bị cáo Nguyễn Kim P và Nguyễn Quỳnh A phạm tội Tổ chức Đánh bạc.
# - Bị cáo Nguyễn Thu H phạm tội Đánh bạc.
# 2. Về hình phạt
# 2.1. Căn cứ vào điểm c khoản 1, 3 Điều 322; điểm s khoản 1, khoản 2 Điều
# 51; điểm g khoản 1 Điều 52, Điều 17, 38, 58 của Bộ luật Hình sự, xử phạt bị cáo
# Nguyễn Kim P 01 (một) năm 04 (bốn) tháng tù, thời hạn chấp hành hình phạt tù
# tính từ ngày đi chấp hành án, bị cáo được trừ thời gian tạm giam 35 ngày (từ ngày
# 10/7/2021 đến ngày 13/8/2021).
# Phạt bổ sung bị cáo Nguyễn Kim P 20.000.000đ (hai mươi triệu đồng) để
# sung ngân sách Nhà nước. Xác nhận bị cáo đã thi hành 5.200.000đ (năm triệu, hai
# trăm nghìn đồng) theo biên lai thu tiền số AA/2021/0000932 ngày 26/01/2022 và
# AA/2021/0000942 ngày 07/4/2022 tại Chi cục Thi hành án dân sự thành phố Lạng
# Sơn, bị cáo còn phải thi hành 14.800.000đ (mười bốn triệu, tám trăm nghìn đồng).
# 2.2. Căn cứ vào điểm c khoản 1 Điều 322; điểm s khoản 1 Điều 51; Điều 17;
# 38; 58 của Bộ luật Hình sự, xử phạt bị cáo Nguyễn Quỳnh A 01 (một) năm tù, thời
# hạn chấp hành hình phạt tù tính từ ngày đi chấp hành án.
# 2.3. Căn cứ vào điểm c khoản 1 Điều 321; điểm i, s khoản 1, khoản 2 Điều
# 51; khoản 1, 2, 5 Điều 65 của Bộ luật Hình sự, xử phạt bị cáo Nguyễn Thu H 01
# (một) năm 04 (bốn) tháng tù cho hưởng án treo, thời gian thử thách 02 (hai) năm 08
# (tám) tháng kể từ ngày tuyên án.
# Giao bị cáo cho Ủy ban nhân dân phường V, thành phố L, tỉnh Lạng Sơn giám
# sát, giáo dục. Gia đình bị cáo có trách nhiệm phối hợp với Ủy ban nhân dân phường V,
# 8<Page:9>thành phố L, tỉnh Lạng Sơn trong việc giám sát, giáo dục bị cáo.
# Đối với bị cáo có hình phạt tù cho hưởng án treo, trong trường hợp người được
# hưởng án treo thay đổi nơi cư trú, thì thực hiện theo quy định tại khoản 3 Điều 92 Luật
# Thi hành án hình sự.
# Trong thời gian thử thách, nếu người được hưởng án treo cố ý vi phạm nghĩa vụ
# theo quy định của Luật Thi hành án hình sự 02 lần trở lên, thì Tòa án có thể quyết định
# buộc người được hưởng án treo phải chấp hành hình phạt tù của bản án đã cho hưởng
# án treo.
# 3. Về xử lý vật chứng:
# Căn cứ vào điểm a khoản 1 Điều 47 của Bộ luật Hình sự; điểm a, c khoản 2,
# điểm a khoản 3 Điều 106 của Bộ luật Tố tụng Hình sự.
# 3.1. Tịch thu, hóa giá nộp ngân sách Nhà nước:
# - 01 (một) Điện thoại Samsung Galaxy A20s màu đen, số IMEI 1:
# 354994111825697, số IMEI 2: 354995111825694
# - 01 (một) Điện thoại di động nhãn hiệu Iphone 6s màu vàng, số IMEI:
# 353259070796177, gắn 01 sim số 0865.828.360
# - 01 (một) Điện thoại di động nhãn hiệu Iphone 12promax, số IMEI:
# 352048884774533, gắn 01 sim số 0983.275.345
# - 01 (một) Máy tính cầm tay Casio; 01 (một) máy tính cầm tay nhãn hiệu Casio
# DS-3018 màu sơn bạc - đen.
# 3.2. Trả lại cho các bị cáo:
# - Trả lại cho bị cáo Nguyễn Kim P: 01 (một) Điện thoại di động nhãn hiệu
# Iphone 7plus màu đen, số IMEI: 355838082346036, gắn 01 sim số 0857.087.892
# - Trả lại cho bị cáo Nguyễn Quỳnh A: 01 (một) Điện thoại Samsung Galaxy J2
# Prime, màu vàng, số IMEI 1: 357161095797295, số IMEI 2: 357162095797293, gắn
# 01 sim số 0969225630 và 01 sim số 0327853635.
# 3.3. Tịch thu, tiêu hủy:
# - 01 (một) Vỏ hộp điện thoại nhãn hiệu Mobistar bên trong có: 01 (một) cáp đề
# ghi ngày 03/5/2021; 03 (ba) tờ giấy dòng kẻ ngang loại giấy vở Hồng Hà có ghi nhiều
# chữ số, 01 (một) tờ giấy dòng kẻ ngang loại giấy vở Hải Tiến có ghi nhiều chữ số;
# - 01 (một) Hợp đồng đại lý bán vé xổ số kiến thiết số 14/HĐ-ĐL/2021 giữa
# Công ty TNHH MTV Xổ số kiến thiết với Nguyễn Quỳnh A;
# - 02 (hai) Tờ giấy dòng kẻ ngang loại giấy vở Hồng Hà có ghi nhiều chữ số;
# - 01 (một) Quyển sổ giả da màu đen kích thước 7,5x10x5cm; độ dày 0,5cm, có
# 08 (tám) tờ giấy ghi nhiều chữ số, bên trong kẹp 01 (một) mảnh giấy có kích thước
# 8,5x4,2cm ghi nhiều chữ số, 01 (một) mảnh giấy có kích thước 10x7,5cm ghi "Hoa
# hồng T3" và nhiều chữ số.
# - 01 (một) Sổ đại lý bán vé số, lô tô, cáp số, trên bìa sổ ghi tên Nguyễn Quỳnh
# A, có 02 (hai) tờ giấy ghi nhiều chữ số;
# 9<Page:10>- 01 (một) Quyển giáo án dòng kẻ ngang kích thước 810x297mm, trên bìa có
# ghi nhiều chữ số, bên trong có 14 tờ giấy ghi nhiều chữ số
# - 01 (một) Quyển sổ Subject B5 kẻ ngang 300 trang cả bìa kích thước
# 175x250mm;
# - 01 (một) Quyển sổ ô ly, kích thước 90x140mm.
# (Những vật chứng trên đang được lưu giữ tại Chi cục Thi hành án dân sự
# thành phố L, có đặc điểm như được mô tả trong biên bản giao nhận vật chứng ngày
# 14/01/2022 giữa Cơ quan Cảnh sát điều tra Công an thành phố Lạng Sơn và Chi
# cục Thi hành án dân sự thành phố L).
# 4. Về án phí:
# Căn cứ vào khoản 2 Điều 136 Bộ luật Tố tụng hình sự; điểm a khoản 1 Điều
# 23 Nghị quyết 326/2016/UBTVQH14 ngày 30/12/2016 của Ủy ban thường vụ
# Quốc hội quy định về mức thu, miễn, giảm, thu, nộp, quản lý và sử dụng án phí và
# lệ phí Tòa án: Buộc bị cáo Nguyễn Kim P, Nguyễn Quỳnh A, Nguyễn Thu H mỗi
# bị cáo phải chịu 200.000 đồng (hai trăm nghìn đồng) án phí hình sự sơ thẩm để nộp
# ngân sách Nhà nước. Xác nhận bị cáo Nguyễn Quỳnh A, Nguyễn Thu H đã nộp
# theo biên lai AA/2021/0000944, AA/2021/0000943 ngày 07/4/2022 tại Chi cục thi
# hành án dân sự thành phố L.
# Các bị cáo có mặt tại phiên tòa có quyền kháng cáo bản án trong thời hạn 15
# ngày kể từ ngày tuyên án, những người có quyền lợi nghĩa vụ liên quan đến vụ án
# vắng mặt tại phiên tòa có quyền kháng cáo bản án trong thời hạn 15 ngày kể từ
# ngày nhận được bản án hoặc ngày bản án được niêm yết.
# Trường hợp bản án được thi hành theo quy định tại Điều 2 Luật Thi hành án
# dân sự thì người được thi hành án dân sự, người phải thi hành án dân sự có quyền
# thỏa thuận thi hành án, quyền yêu cầu thi hành án, tự nguyện thi hành án hoặc bị
# cưỡng chế thi hành án theo quy định tại các điều 6, 7 và 9 Luật Thi hành án dân sự;
# thời hiệu thi hành án được thực hiện theo quy định tại Điều 30 Luật Thi hành án
# dân sự.
# 10

# %% [markdown]
# ## format date

# %%
def convert_to_standard_date(date_str):
    if re.match(r'\d{4}-\d{2}-\d{2}', date_str):
        return date_str
    # Handling Vietnamese format "dd tháng mm năm yyyy"
    viet_date_match = re.match(r'(\d{1,2}) tháng (\d{1,2}) năm (\d{4})', date_str)
    if viet_date_match:
        day = viet_date_match.group(1).zfill(2)
        month = viet_date_match.group(2).zfill(2)
        year = viet_date_match.group(3)
        return f"{year}-{month}-{day}"
    
    # Handling "dd-mm-yyyy" format
    try:
        return datetime.strptime(date_str, '%d/%m/%Y').strftime('%Y-%m-%d')
    except ValueError:
        pass
    
    # Handling "yyyy-mm" format, assume day as 01
    try:
        return datetime.strptime(date_str, '%Y-%m').strftime('%Y-%m')
    except ValueError:
        pass
    
    # Handling formats like "yyyy"
    try:
        return datetime.strptime(date_str, '%Y').strftime('%Y')
    except ValueError:
        pass
    
    
    # Handling "no information" or any other text
    if date_str.lower in ['no', 'N/A', 'null']:
        return 'No information'
    
    # Default return None for unhandled cases
    return None

# Apply the function to the birthdate column
df.loc[:,'standardized_birthdate'] = df['birthdate'].apply(convert_to_standard_date)

# Display the DataFrame
df.head()
# Out:
#    extract_id                                           jlr_link         name  \
# 0        5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...     Vi Đức T
# 1        5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...     Vi Văn H
# 2        5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...     Vi Thị B
# 3        5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...  Hoàng Thị Y
# 4        5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...   Đinh Văn H
#
#     birthdate  gender province_name district_name village_name  \
# 0  2004-08-16    Male       Nghệ An     Con Cuông           ĐT
# 1        1982    Male       Nghệ An     Con Cuông           ĐT
# 2        1985  Female       Nghệ An     Con Cuông           ĐT
# 3        1991  Female       Nghệ An            ĐL           LD
# 4        1999    Male       Nghệ An            ĐL        Xóm 8
#
#                                     full_address crime jail jail_duration  \
# 0  Bản ĐT, xã LKh, huyện Con Cuông, tỉnh Nghệ An    no   no            no
# 1  Bản ĐT, xã LKh, huyện Con Cuông, tỉnh Nghệ An    no   no            no
# 2  Bản ĐT, xã LKh, huyện Con Cuông, tỉnh Nghệ An    no   no            no
# 3              LD, xã LS, huyện ĐL, tỉnh Nghệ An    no   no            no
# 4          Xóm 8, xã TS, huyện Đ L, tỉnh Nghệ An    no   no            no
#
#   fine fine_total other_punishment                      time  \
# 0   no         no               no 2024-05-28 18:49:01+00:00
# 1   no         no               no 2024-05-28 18:49:01+00:00
# 2   no         no               no 2024-05-28 18:49:01+00:00
# 3   no         no               no 2024-05-28 18:49:01+00:00
# 4   no         no               no 2024-05-28 18:49:01+00:00
#
#   standardized_birthdate
# 0             2004-08-16
# 1                   1982
# 2                   1985
# 3                   1991
# 4                   1999

# %%
df['standardized_birthdate']
# Out:
# 0        2004-08-16
# 1              1982
# 2              1985
# 3              1991
# 4              1999
#             ...
# 11295          1967
# 11296          1973
# 11297          1965
# 11298          1964
# 11299    1975-01-01
# Name: standardized_birthdate, Length: 11300, dtype: object

# %%
# Filter rows where length of 'standardized_birthdate' is less than 10
filtered_df = df[df['standardized_birthdate'].str.len() < 8]
filtered_df['standardized_birthdate'].unique()
# Out:
# array(['1982', '1985', '1991', '1999', '2006', '1960', '2002', '1989',
#        '1977', '1980', '1995', '1979', '1987', '1983', '1959', '1963',
#        '2001', '1962', '1961', '2007', '1994', '1958', '1993', '1996',
#        '1966', '1974', '1973', '1967', '1972', '2003', '1998', '1988',
#        '1970', '1976', '1957', '1964', '1971', '1965', '1997', '1992',
#        '1953', '1942', '1978', '1990', '1986', '1969', '1952', '1955',
#        '1654', '1968', '1981', '2017', '1975', '1984', '2000', '2012',
#        '1970-07', '2004', '1956', '1938', '1937', '1949', '1950', '1939',
#        '1947', '1946', '2009', '2022', '1954', '2018', '1945', '1951',
#        '1940'], dtype=object)

# %%
filtered_df
# Out:
#        extract_id                                           jlr_link  \
# 1            5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...
# 2            5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...
# 3            5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...
# 4            5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...
# 5            5116  https://congbobanan.toaan.gov.vn/2ta1153558t1c...
# ...           ...                                                ...
# 11294        1430  https://congbobanan.toaan.gov.vn/2ta1066372t1c...
# 11295        1430  https://congbobanan.toaan.gov.vn/2ta1066372t1c...
# 11296        1430  https://congbobanan.toaan.gov.vn/2ta1066372t1c...
# 11297        1430  https://congbobanan.toaan.gov.vn/2ta1066372t1c...
# 11298        1430  https://congbobanan.toaan.gov.vn/2ta1066372t1c...
#
#                  name birthdate  gender province_name district_name  \
# 1            Vi Văn H      1982    Male       Nghệ An     Con Cuông
# 2            Vi Thị B      1985  Female       Nghệ An     Con Cuông
# 3         Hoàng Thị Y      1991  Female       Nghệ An            ĐL
# 4          Đinh Văn H      1999    Male       Nghệ An            ĐL
# 5          Vi Khánh H      2006    Male       Nghệ An     Con Cuông
# ...               ...       ...     ...           ...           ...
# 11294   Phùng Phước A      1952    Male      Trà Vinh             C
# 11295      Trần Thị L      1967  Female      Trà Vinh             C
# 11296  Trần Thị Lệ Tr      1973  Female      Trà Vinh             C
# 11297      Trần Thị O      1965  Female      Trà Vinh             C
# 11298    Trương Thị D      1964  Female      Trà Vinh             C
#
#       village_name                                      full_address  \
# 1               ĐT     Bản ĐT, xã LKh, huyện Con Cuông, tỉnh Nghệ An
# 2               ĐT     Bản ĐT, xã LKh, huyện Con Cuông, tỉnh Nghệ An
# 3               LD                 LD, xã LS, huyện ĐL, tỉnh Nghệ An
# 4            Xóm 8             Xóm 8, xã TS, huyện Đ L, tỉnh Nghệ An
# 5              ChĐ  Thôn ChĐ, xã ChKh, huyện Con Cuông, tỉnh Nghệ An
# ...            ...                                               ...
# 11294            H                ấp H, xã P, huyện C, tỉnh Trà Vinh
# 11295            H                ấp H, xã P, huyện C, tỉnh Trà Vinh
# 11296            H                ấp H, xã P, huyện C, tỉnh Trà Vinh
# 11297            H                ấp H, xã P, huyện C, tỉnh Trà Vinh
# 11298            H                ấp H, xã P, huyện C, tỉnh Trà Vinh
#
#                                       crime jail jail_duration fine  \
# 1                                        no   no            no   no
# 2                                        no   no            no   no
# 3                                        no   no            no   no
# 4                                        no   no            no   no
# 5                                        no   no            no   no
# ...                                     ...  ...           ...  ...
# 11294  Fraudulent appropriation of property   no            no  yes
# 11295  Fraudulent appropriation of property   no            no  yes
# 11296  Fraudulent appropriation of property   no            no  yes
# 11297  Fraudulent appropriation of property   no            no  yes
# 11298  Fraudulent appropriation of property   no            no  yes
#
#        fine_total other_punishment                      time  \
# 1              no               no 2024-05-28 18:49:01+00:00
# 2              no               no 2024-05-28 18:49:01+00:00
# 3              no               no 2024-05-28 18:49:01+00:00
# 4              no               no 2024-05-28 18:49:01+00:00
# 5              no               no 2024-05-28 18:49:01+00:00
# ...           ...              ...                       ...
# 11294   4,561,765               no 2024-05-25 02:59:50+00:00
# 11295   5,834,081               no 2024-05-25 02:59:50+00:00
# 11296  32,317,893               no 2024-05-25 02:59:50+00:00
# 11297  61,696,162               no 2024-05-25 02:59:50+00:00
# 11298  18,543,591               no 2024-05-25 02:59:50+00:00
#
#       standardized_birthdate
# 1                       1982
# 2                       1985
# 3                       1991
# 4                       1999
# 5                       2006
# ...                      ...
# 11294                   1952
# 11295                   1967
# 11296                   1973
# 11297                   1965
# 11298                   1964
#
# [1472 rows x 17 columns]

# %% [markdown]
# ## filter out without crime

# %%
mask = ~(df[['crime', 'jail', 'jail_duration', 'fine', 'fine_total', 'other_punishment']].isin(['no', 'N/A', 'NO', 'No',
                                                                                                'No Action Taken',
                                                                                                'no information', 'No information',
                                                                                                'null', 'null', 'None',
                                                                                                 'No Crime', 'No crime',
                                                                                                 'No criminal charge',
                                                                                                 'No criminal record',
                                                                                                 'Not specified'])).all(axis=1)

# Filter the DataFrame using the mask
df = df[mask]

df.head()
# Out:
#     extract_id                                           jlr_link  \
# 12        5354  https://congbobanan.toaan.gov.vn/2ta816509t1cv...
# 13        5354  https://congbobanan.toaan.gov.vn/2ta816509t1cv...
# 14        5359  https://congbobanan.toaan.gov.vn/2ta260824t1cv...
# 15        5359  https://congbobanan.toaan.gov.vn/2ta260824t1cv...
# 16        5282  https://congbobanan.toaan.gov.vn/2ta636354t1cv...
#
#               name   birthdate gender province_name district_name  \
# 12   Nguyễn Đình T  1998-11-16   Male       Bắc Kạn             B
# 13      Nông Văn T  1995-02-07   Male       Bắc Kạn             B
# 14    Doãn Dương D  1976-11-20   Male    Quảng Bình             B
# 15     Dương Đức Đ  1972-11-05   Male    Quảng Bình             B
# 16  Nguyễn Thanh B  1986-05-25   Male      Lâm Đồng         TP. B
#
#    village_name                                  full_address  crime jail  \
# 12            Đ     Thôn Đ, thị trấn P, huyện B, tỉnh Bắc Kạn  Theft  yes
# 13            T           Thôn T, xã V, huyện B, tỉnh Bắc Kạn  Theft  yes
# 14           Tâ       thôn Tâ, xã C, huyện B, tỉnh Quảng Bình  Theft   no
# 15            3        thôn 3, xã Đ, huyện B, tỉnh Quảng Bình  Theft   no
# 16     Phường X  Số C đường T, Phường X, TP. B, tỉnh Lâm Đồng  Theft  yes
#
#    jail_duration fine fine_total                      other_punishment  \
# 12     18 months   no         no                                    no
# 13     36 months   no         no                                    no
# 14            no   no         no  15 months of non-custodial probation
# 15            no   no         no  15 months of non-custodial probation
# 16      9 months   no         no                                    no
#
#                         time standardized_birthdate
# 12 2024-05-29 11:43:55+00:00             1998-11-16
# 13 2024-05-29 11:43:55+00:00             1995-02-07
# 14 2024-05-29 11:45:32+00:00             1976-11-20
# 15 2024-05-29 11:45:32+00:00             1972-11-05
# 16 2024-05-29 09:25:54+00:00             1986-05-25

# %% [markdown]
# ## format jail_duration

# %%
#filtered_df['jail_duration'].unique()

# %%
def convert_to_months(duration):
    # Define conversion rates
    year_to_month = 12
    month_to_month = 1

    # Dictionary for Vietnamese translations
    vietnamese_to_english = {
        'năm': 'year',
        'tháng': 'month',
        'chung thân': 'life imprisonment',
        'tù chung thân': 'life imprisonment',
        'mười hai': 'twelve',
        'Chín': 'nine',
        'Hai': 'two',
        'Sáu': 'six',
        'bảy': 'seven',
        'Một': 'one',
        '03': 'three',
        '06': 'six',
        '07': 'seven',
        '08': 'eight',
        '09': 'nine'
    }

    # Replace Vietnamese terms with English equivalents
    for viet, eng in vietnamese_to_english.items():
        duration = duration.replace(viet, eng)

    # Handle special cases
    if 'life' in duration.lower():
        return 'Life Imprisonment'
    if 'death' in duration.lower():
        return 'Death Sentence'
    if 'no' in duration.lower() or 'yes' in duration.lower():
        return 'Not Applicable'

    # Extract numbers and units
    numbers = re.findall(r'\d+', duration)
    units = re.findall(r'year|month', duration, re.IGNORECASE)

    # Convert all to months
    total_months = 0
    for number, unit in zip(numbers, units):
        if 'year' in unit.lower():
            total_months += int(number) * year_to_month
        elif 'month' in unit.lower():
            total_months += int(number) * month_to_month

    return total_months

df.loc[:, 'standardized_jail_duration'] = df['jail_duration'].apply(convert_to_months)

df['standardized_jail_duration'].unique()
# Out:
# array([18, 36, 'Not Applicable', 9, 12, 15, 0, 6, 39, 24, 3, 27, 96, 84,
#        48, 60, 45, 81, 93, 30, 42, 7, 8, 11, 16, 13, 21, 72,
#        'Life Imprisonment', 192, 126, 108, 204, 34, 5, 73, 4, 20, 14, 78,
#        54, 26, 180, 32, 28, 132, 144, 31, 33, 120, 87, 10, 66, 90, 22,
#        240, 216, 37, 162, 102, 17, 51, 156, 82, 19, 50, 360, 136, 63, 62,
#        150, 46, 25, 57, 40, 38, 41, 107, 'Death Sentence', 88, 99, 174,
#        186, 198, 69, 74, 29, 312, 252, 228, 141, 264, 123, 114, 105, 138,
#        210, 23, 92, 348, 49, 303, 285, 145, 168, 110, 106, 147, 190, 43,
#        86, 44, 52, 61, 297, 291, 35, 234, 68, 336, 249, 219, 129],
#       dtype=object)

# %% [markdown]
# ## format fine total

# %%
#df['fine_total'].unique()

# %%
def standardize_amount(amount):
    # Check for monthly payments and extract the number of months if present
    monthly_payment_match = re.search(r'(\d+([.,]\d+)*)\s*VND/month\s*for\s*(\d+)\s*months', amount, re.IGNORECASE)
    if monthly_payment_match:
        monthly_payment = monthly_payment_match.group(1).replace('.', '').replace(',', '')
        months = int(monthly_payment_match.group(3))
        return round(float(monthly_payment) * months)  # Return the total payment over the period
    
    # Handle ranges (e.g., "10.000.000-15.000.000")
    range_match = re.search(r'(\d+[.,\d]*)\s*[-đồng tođến]+\s*(\d+[.,\d]*)', amount, re.IGNORECASE)
    if range_match:
        low_amount = range_match.group(1).replace('.', '').replace(',', '')
        high_amount = range_match.group(2).replace('.', '').replace(',', '')
        # Convert to float and take the average of the range
        try:
            low_amount = float(low_amount)
            high_amount = float(high_amount)
            return round((low_amount + high_amount) / 2)
        except ValueError:
            return 0
        
    # Remove non-numeric characters but keep the decimal point and comma
    amount = re.sub(r'[^\d.,]', '', amount)
    # Determine if commas or periods are used as thousand separators or decimal points
    if ',' in amount and '.' in amount:
        if amount.find(',') < amount.find('.'):
            amount = amount.replace(',', '')
        else:
            amount = amount.replace('.', '')
            
    # Replace remaining commas with dots if they are used as decimal separators
    amount = amount.replace('.', ',')
    amount = amount.replace(',', '')
    # Convert to float and round to nearest integer (assuming no cents are needed)
    try:
        standardized_amount = eval(amount)
    except:
        standardized_amount = 0
    return standardized_amount

df.loc[:, 'standardized_fine_total'] = df['fine_total'].apply(standardize_amount)

df['standardized_fine_total'].unique()
# Out:
# array([         0,    5000000,     200000,   12000000,     770000,
#           2500000,  149000000,  200000000,  182000000,   35000000,
#          40000000,   32000000,   25000000,   28000000,   22000000,
#          20000000,   10000000,   15000000,  100000000,   30000000,
#           2700000,    7000000,    6000000,   60000000,     500000,
#             50000,     950000,   23000000,   21000000,   50000000,
#           1050000,    1000000,    1600000,       5000,    2000000,
#           3800000,    1700000,     260000,   12500000,    1400000,
#            800000,  778801000,     575000,    1500000,    1200000,
#           9500000,    1070000,      80000,  228750000,  246540000,
#         126000000,  210000000,     290000,     750000,    3000000,
#          27000000,         12,   22792500,    2250000,    1800000,
#           1350000,     370000,    9000000,    8000000,     894000,
#          24000000,   68800000,    2870000,   11940000,    1690000,
#           5700000,    6610000,         13,    4000000,     250000,
#        1700000000,    3829800,   19450000,    5200000,   65000000,
#          55000000,     600000,   90076500,    2400000,    1790500,
#            400000,      95000,   97428800,    1936000,    3194000,
#           6600000,      60000,     700000,   78536326,     587000,
#            350000,     300000,    8600000,     100000,     510000,
#         700000000,    7500000,  135200000,  280000000,    2191000,
#          33292000,   80000000,    1457000, 1700996280,   33500000,
#          70000000,    3200000,    2300000,          9,    1750000,
#            433000,   10473200,   45000000,   18000000,   11000000,
#          70500000,    1100000,   50961890,  320000000,  310000000,
#         235000000,  191114499,    1300000,    2108000,    1774000,
#           1550000,    4500000,     660000,   17600000,   21446000,
#          57100000,     520000,    1250000,    1900000,     375000,
#          26000000,  800000000,  120000000,         15,         10,
#            183300,  170000000,  130000000,   90000000,    5916000,
#           8750000,    8154706,    3561579,    9792971,   10740349,
#           2740349,    6076500,    4048000,   39314646,  136050267,
#           4561765,   25789875,   33110923,   11367349,   22464111,
#            220000,   13217000,         24,         18,  150000000,
#        1200000000, 1000000000, 1050000000,    1981000,    2200000,
#           4600000,   28368000,     900000,   65366000,  172500000,
#         198600000,  154000000,  160000000,    6700000,   10200000,
#           4700000,   17500000,    6956533,   20700000,    3750000,
#            895000,    5800000,    2793000,     133400,    4914000,
#           2332200,    3500000,     150000,    1049400,     490000,
#            285000,   96000000,   14000000,    5660000,   10800000,
#              2000,   13000000,   31849000,    1375000,     798333,
#           3300000,    8130475,    4878258,    3089580,    3902628,
#            870000, 1270000000,   12410000,  125741000,   49000000,
#            550000,    8700000,   16450000,    2800000,     960000,
#            210000,     822000,     222000,   56415000,   88200000,
#          38167000,   10480000,   20200000,   72550000,   40250000,
#          52250000,   46950000,  169000000,  194466151,   10500000,
#           5220000,   14814700,   88294814,     180000,    9800000,
#          13471000,   13940000,   50805000,    1711200,   76449420,
#          38981000,   37311000,   27690000,   84376000,   18710000,
#           5550000,    2330000,  287100000,   14900000,  290600000,
#           4358565,   18825817,    6405215,   15445500,   14496875,
#          88992533,   27977383,    7633000,    3134474,    1663849,
#            979375,   12171344,    3261765,   22351581,   12671111,
#          10238015,   14636636,    5834081,   32317893,   61696162,
#          18543591])

# %%
# Correct filtering condition
pdf = df[(df['standardized_fine_total'] < 1000) & (df['standardized_fine_total'] > 0)]
pdf
# # Iterate over the filtered DataFrame and print the results
# for index, row in pdf.iterrows():
#     print(row['fine_total'], row['standardized_fine_total'])
# Out:
#       extract_id                                           jlr_link  \
# 2787        3953  https://congbobanan.toaan.gov.vn/2ta558092t1cv...
# 3037        4683  https://congbobanan.toaan.gov.vn/2ta801290t1cv...
# 3038        4683  https://congbobanan.toaan.gov.vn/2ta801290t1cv...
# 3039        4683  https://congbobanan.toaan.gov.vn/2ta801290t1cv...
# 3040        4683  https://congbobanan.toaan.gov.vn/2ta801290t1cv...
# 3041        4683  https://congbobanan.toaan.gov.vn/2ta801290t1cv...
# 4154        5529  https://congbobanan.toaan.gov.vn/2ta1033019t1c...
# 6508         600  https://congbobanan.toaan.gov.vn/2ta711148t1cv...
# 6509         600  https://congbobanan.toaan.gov.vn/2ta711148t1cv...
# 7396        2332  https://congbobanan.toaan.gov.vn/2ta687618t1cv...
# 7397        2332  https://congbobanan.toaan.gov.vn/2ta687618t1cv...
# 7398        2332  https://congbobanan.toaan.gov.vn/2ta687618t1cv...
# 7399        2332  https://congbobanan.toaan.gov.vn/2ta687618t1cv...
# 7400        2332  https://congbobanan.toaan.gov.vn/2ta687618t1cv...
# 7401        2332  https://congbobanan.toaan.gov.vn/2ta687618t1cv...
#
#                 name   birthdate  gender province_name district_name  \
# 2787  Lại Thị Ngọc N  1980-05-12  Female             A             V
# 3037        Ma Văn C  1962-02-17    Male             Đ             K
# 3038        Ma Văn Đ  1986-11-25    Male             Đ             K
# 3039        Ma Văn L  1991-05-27    Male             Đ             K
# 3040      Ma Văn Nam  1987-05-12    Male             Đ             K
# 3041   Nguyễn Minh T        1978    Male             Đ             K
# 4154      Trần Thị N        1972  Female     Vĩnh Phúc             B
# 6508     Phạm Tùng Đ  1992-08-19    Male   Thái Nguyên      thị xã P
# 6509      Đào Văn Ng  1973-07-02    Male             N       huyện V
# 7396     Trần Mạnh Q  1996-05-14    Male       Phú Thọ     Thanh Sơn
# 7397      Đinh Văn P  1993-09-23    Male       Phú Thọ     Thanh Sơn
# 7398     Đinh Công Đ  2002-03-21    Male       Phú Thọ       Yên Lập
# 7399        Hà Văn G  2004-03-24    Male       Phú Thọ       Tân Sơn
# 7400     Hoàng Anh D  2002-12-23    Male       Phú Thọ       Yên Lập
# 7401  Đinh Đặng Sỹ H  2003-09-27    Male       Phú Thọ     Thanh Sơn
#
#                 village_name  \
# 2787                      TH
# 3037                       X
# 3038                       E
# 3039                       X
# 3040                       X
# 3041                       X
# 4154                       Đ
# 6508  Tổ dân phố L, phường B
# 6509                    Xã T
# 7396                       L
# 7397                       L
# 7398                       N
# 7399                       T
# 7400                       N
# 7401                       S
#
#                                            full_address  \
# 2787             Khối TH, phường H, thành phố V, tỉnh A
# 3037                      Thôn X, xã E, huyện K, tỉnh Đ
# 3038                      Thôn E, xã E, huyện K, tỉnh Đ
# 3039                      Thôn X, xã E, huyện K, tỉnh Đ
# 3040                      Thôn X, xã E, huyện K, tỉnh Đ
# 3041                      Thôn X, xã E, huyện K, tỉnh Đ
# 4154  Tổ dân phố Đ, thị trấn L, huyện B, tỉnh Vĩnh Phúc
# 6508  Tổ dân phố L, phường B, thị xã P, tỉnh Thái Ng...
# 6509  Tổ dân phố T, phường P, thành phố S, tỉnh Thái...
# 7396         Khu D, xã L, huyện Thanh Sơn, tỉnh Phú Thọ
# 7397         Khu G, xã L, huyện Thanh Sơn, tỉnh Phú Thọ
# 7398          Khu 21, xã N, huyện Yên Lập, tỉnh Phú Thọ
# 7399           Khu M, xã T, huyện Tân Sơn, tỉnh Phú Thọ
# 7400           Khu 3, xã N, huyện Yên Lập, tỉnh Phú Thọ
# 7401         Khu L, xã S, huyện Thanh Sơn, tỉnh Phú Thọ
#
#                                                crime jail jail_duration fine  \
# 2787                                        Gambling   no            no  yes
# 3037                                        Gambling   no            no  yes
# 3038                                        Gambling   no            no  yes
# 3039                                        Gambling   no            no  yes
# 3040                                        Gambling   no            no  yes
# 3041                                        Gambling   no            no  yes
# 4154  Allowing unqualified person to drive a vehicle   no            no  yes
# 6508                                 False reporting   no            no  yes
# 6509                                 False reporting   no            no  yes
# 7396                               Illegal Detention   no            no  yes
# 7397                               Illegal Detention   no            no  yes
# 7398                               Illegal Detention   no            no  yes
# 7399                               Illegal Detention   no            no  yes
# 7400                               Illegal Detention   no            no  yes
# 7401                               Illegal Detention   no            no  yes
#
#                          fine_total  \
# 2787                      12 months
# 3037                1 year 3 months
# 3038                1 year 3 months
# 3039                1 year 3 months
# 3040                1 year 3 months
# 3041                1 year 3 months
# 4154  9 months non-custodial reform
# 6508          15% of monthly income
# 6509          10% of monthly income
# 7396                      24 months
# 7397                      24 months
# 7398                      24 months
# 7399                      18 months
# 7400                      18 months
# 7401                      18 months
#
#                                        other_punishment  \
# 2787                                                 no
# 3037                                                 no
# 3038                                                 no
# 3039                                                 no
# 3040                                                 no
# 3041                                                 no
# 4154                                                 no
# 6508                 Non-custodial reform for 12 months
# 6509  Non-custodial reform for 9 months, deducting 2...
# 7396                            Probation for 48 months
# 7397                                                 no
# 7398                                                 no
# 7399                            Probation for 36 months
# 7400                            Probation for 36 months
# 7401                            Probation for 36 months
#
#                           time standardized_birthdate  \
# 2787 2024-05-28 15:55:10+00:00             1980-05-12
# 3037 2024-05-28 17:44:56+00:00             1962-02-17
# 3038 2024-05-28 17:44:56+00:00             1986-11-25
# 3039 2024-05-28 17:44:56+00:00             1991-05-27
# 3040 2024-05-28 17:44:56+00:00             1987-05-12
# 3041 2024-05-28 17:44:56+00:00                   1978
# 4154 2024-05-29 14:33:27+00:00                   1972
# 6508 2024-05-23 19:57:29+00:00             1992-08-19
# 6509 2024-05-23 19:57:29+00:00             1973-07-02
# 7396 2024-05-26 18:25:39+00:00             1996-05-14
# 7397 2024-05-26 18:25:39+00:00             1993-09-23
# 7398 2024-05-26 18:25:39+00:00             2002-03-21
# 7399 2024-05-26 18:25:39+00:00             2004-03-24
# 7400 2024-05-26 18:25:39+00:00             2002-12-23
# 7401 2024-05-26 18:25:39+00:00             2003-09-27
#
#      standardized_jail_duration  standardized_fine_total
# 2787             Not Applicable                       12
# 3037             Not Applicable                       13
# 3038             Not Applicable                       13
# 3039             Not Applicable                       13
# 3040             Not Applicable                       13
# 3041             Not Applicable                       13
# 4154             Not Applicable                        9
# 6508             Not Applicable                       15
# 6509             Not Applicable                       10
# 7396             Not Applicable                       24
# 7397             Not Applicable                       24
# 7398             Not Applicable                       24
# 7399             Not Applicable                       18
# 7400             Not Applicable                       18
# 7401             Not Applicable                       18

# %% [markdown]
# ## start comparison

# %%
name = "Vũ Văn Hùng"
birthdate = "1985-11-10"
province_name = "Bình Dương"
district_name = "Thủ Dầu Một"
village_name = "Phú Cường"

# %%
similarities_name = df['name'].apply(lambda x: fuzz.partial_ratio(name, x))
similarities_birthdate = df['birthdate'].apply(lambda x: fuzz.ratio(str(birthdate), str(x)))
similarities_province = df['province_name'].apply(lambda x: fuzz.ratio(province_name, x))
similarities_district = df['district_name'].apply(lambda x: fuzz.ratio(district_name, x))
similarities_village = df['village_name'].apply(lambda x:fuzz.ratio(village_name, x))

# Combine the similarities
#total_similarity = similarities_name + similarities_birthdate + similarities_province + similarities_district + similarities_village
total_similarity = similarities_name * 0.5 + similarities_birthdate * 0.1 + similarities_province * 0.2 + similarities_district * 0.1 + similarities_village * 0.1 

# Combine the similarities and original DataFrame
df['total_similarity'] = total_similarity

# Retrieve the top 10 most similar rows
top_10_rows = df.nlargest(10, 'total_similarity')

# %%
top_10_rows
# Out:
#        extract_id                                           jlr_link  \
# 1724         3983  https://congbobanan.toaan.gov.vn/2ta854842t1cv...
# 953          4317  https://congbobanan.toaan.gov.vn/2ta66924t1cvn...
# 955          4317  https://congbobanan.toaan.gov.vn/2ta66924t1cvn...
# 8701           94  https://congbobanan.toaan.gov.vn/2ta566021t1cv...
# 1176         4164  https://congbobanan.toaan.gov.vn/2ta258115t1cv...
# 535          6383  https://congbobanan.toaan.gov.vn/2ta203663t1cv...
# 4688         5510  https://congbobanan.toaan.gov.vn/2ta1065710t1c...
# 3431         6712  https://congbobanan.toaan.gov.vn/2ta910753t1cv...
# 10245        1658  https://congbobanan.toaan.gov.vn/2ta858741t1cv...
# 2597         3798  https://congbobanan.toaan.gov.vn/2ta287161t1cv...
#
#            name   birthdate gender province_name district_name  \
# 1724   Vũ Văn H  1989-04-25   Male    Bình Dương             P
# 953    Vũ Văn H  2000-10-15   Male     Hải Dương   Thành phố H
# 955    Vũ Văn M  1999-12-09   Male     Hải Dương          tp H
# 8701   Vũ Văn T  1980-10-04   Male     Hải Dương             C
# 1176   Võ Văn L  1995-01-30   Male    Bình Dương             D
# 535    Vũ Văn D  1991-01-10   Male     Hải Dương             T
# 4688   Tạ Văn T  1968-10-20   Male    Bình Dương      Thuận An
# 3431   Vũ Văn C  1983-09-02   Male     Hải Phòng        quận N
# 10245  Vũ Văn Đ  1997-01-13   Male    Quảng Ninh      thị xã Q
# 2597   Vũ Văn H  2003-12-05   Male     Hải Dương             G
#
#                                   village_name  \
# 1724                                        AT
# 953                                 Đinh Văn T
# 955                                  Vũ Khâm L
# 8701                           khu dân cư số 8
# 1176                                         A
# 535                                         Np
# 4688   số nhà 3/15C, tổ 3, khu phố B, phường B
# 3431                                  phường L
# 10245                          Khu 8, phường Y
# 2597                                         K
#
#                                             full_address  \
# 1724              Ấp TB, xã AT, huyện P, tỉnh Bình Dương
# 953    số 22/88 Đinh Văn T, phường B, Thành phố H, tỉ...
# 955        351 Vũ Khâm L, phường H, tp H, tỉnh Hải Dương
# 8701   khu dân cư số 8, phường P, thành phố C, tỉnh H...
# 1176                Ấp A, xã C, huyện D, tỉnh Bình Dương
# 535                       Thôn A, xã Np, huyện T, tỉnh H
# 4688   số nhà 3/15C, tổ 3, khu phố B, phường B, thành...
# 3431   Số 8/214 đường L, phường L, quận N, thành phố ...
# 10245         Khu 8, phường Y, thị xã Q, tỉnh Quảng Ninh
# 2597               thôn K, xã T, huyện G, tỉnh Hải Dương
#
#                                                   crime jail    jail_duration  \
# 1724                                Possession of Drugs  yes  1 year 3 months
# 953                                               Theft   no               no
# 955                                               Theft   no               no
# 8701                                           Gambling  yes         8 months
# 1176                                           Drug use   no               no
# 535                                            Gambling   no               no
# 4688                                           Gambling   no               no
# 3431                                              Theft  yes        18 months
# 10245                    Tàng trữ trái phép chất ma túy  yes        18 months
# 2597   Causing public disorder with rudimentary weapons  yes        12 months
#
#       fine  fine_total                                   other_punishment  \
# 1724    no          no                                                 no
# 953     no          no                  10 months of non-custodial reform
# 955     no          no                   8 months of non-custodial reform
# 8701   yes  10,000,000                                                 no
# 1176    no          no  Forced drug rehabilitation for 14 months at Cơ...
# 535     no          no                              9 months of probation
# 4688   yes  20.000.000                                                 no
# 3431    no          no                                                 no
# 10245   no          no                                                 no
# 2597    no          no                                                 no
#
#                            time standardized_birthdate  \
# 1724  2024-05-28 15:59:33+00:00                   None
# 953   2024-05-28 16:49:55+00:00                   None
# 955   2024-05-28 16:49:55+00:00                   None
# 8701  2024-05-23 16:04:40+00:00                   None
# 1176  2024-05-28 16:27:27+00:00                   None
# 535   2024-05-29 20:12:18+00:00                   None
# 4688  2024-05-29 14:26:51+00:00                   None
# 3431  2024-05-30 10:09:19+00:00                   None
# 10245 2024-05-26 15:40:06+00:00                   None
# 2597  2024-05-28 15:10:56+00:00                   None
#
#       standardized_jail_duration  standardized_fine_total  total_similarity
# 1724                          15                        0         75.000000
# 953               Not Applicable                        0         73.425837
# 955               Not Applicable                        0         68.853801
# 8701                           8                 10000000         68.798246
# 1176              Not Applicable                        0         68.666667
# 535               Not Applicable                        0         67.964912
# 4688              Not Applicable                 20000000         67.460526
# 3431                          18                        0         67.217750
# 10245                         18                        0         66.824561
# 2597                          12                        0         66.631579

# %%
from rapidfuzz import fuzz, process
from google.cloud import bigquery
from datetime import datetime
import pandas as pd
import numpy as np
import re

def read_bq():
    client = bigquery.Client()
    
    query = f"""
        SELECT *
        FROM `intern-project-415606.Criminal_Dataset.criminal_data_gemini`
    """
    
    try:
        query_job = client.query(query)
        df = query_job.to_dataframe()
        return df
    except Exception as e:
        print(f"Error: {e}")

# Function to convert various date formats to yyyy-mm-dd    
def convert_to_standard_date(date_str):
    if re.match(r'\d{4}-\d{2}-\d{2}', date_str):
        return date_str
    # Handling Vietnamese format "dd tháng mm năm yyyy"
    viet_date_match = re.match(r'(\d{1,2}) tháng (\d{1,2}) năm (\d{4})', date_str)
    if viet_date_match:
        day = viet_date_match.group(1).zfill(2)
        month = viet_date_match.group(2).zfill(2)
        year = viet_date_match.group(3)
        return f"{year}-{month}-{day}"
    
    # Handling "dd-mm-yyyy" format
    try:
        return datetime.strptime(date_str, '%d/%m/%Y').strftime('%Y-%m-%d')
    except ValueError:
        pass
    
    # Handling "yyyy-mm" format, assume day as 01
    try:
        return datetime.strptime(date_str, '%Y-%m').strftime('%Y-%m')
    except ValueError:
        pass
    
    # Handling formats like "yyyy"
    try:
        return datetime.strptime(date_str, '%Y').strftime('%Y')
    except ValueError:
        pass
    
    
    # Handling "no information" or any other text
    if date_str.lower in ['no', 'N/A', 'null']:
        return 'No information'
    
    # Default return None for unhandled cases
    return None

# Define the mask to filter out specific strings
def filter_specific_strings(df):
    mask = ~(df[['crime', 'jail', 'jail_duration', 'fine', 'fine_total', 'other_punishment']]
              .isin(['no', 'N/A', 'NO', 'No', 'No Action Taken', 'no information', 'No information', 'null', 'None', 
                     'No Crime', 'No crime', 'No criminal charge', 'No criminal record', 'Not specified'])).all(axis=1)
    # Filter the DataFrame using the mask
    df = df[mask]
    return df

# Function to convert jail duration to months
def convert_to_months(duration):
    # Define conversion rates
    year_to_month = 12
    month_to_month = 1

    # Dictionary for Vietnamese translations
    vietnamese_to_english = {
        'năm': 'year',
        'tháng': 'month',
        'chung thân': 'life imprisonment',
        'tù chung thân': 'life imprisonment',
        'mười hai': 'twelve',
        'Chín': 'nine',
        'Hai': 'two',
        'Sáu': 'six',
        'bảy': 'seven',
        'Một': 'one',
        '03': 'three',
        '06': 'six',
        '07': 'seven',
        '08': 'eight',
        '09': 'nine'
    }

    # Replace Vietnamese terms with English equivalents
    for viet, eng in vietnamese_to_english.items():
        duration = duration.replace(viet, eng)

    # Handle special cases
    if 'life' in duration.lower():
        return 'Life Imprisonment'
    if 'death' in duration.lower():
        return 'Death Sentence'
    if 'no' in duration.lower() or 'yes' in duration.lower():
        return 'Not Applicable'

    # Extract numbers and units
    numbers = re.findall(r'\d+', duration)
    units = re.findall(r'year|month', duration, re.IGNORECASE)

    # Convert all to months
    total_months = 0
    for number, unit in zip(numbers, units):
        if 'year' in unit.lower():
            total_months += int(number) * year_to_month
        elif 'month' in unit.lower():
            total_months += int(number) * month_to_month

    return total_months

def standardize_amount(amount):
    # Check for monthly payments and extract the number of months if present
    monthly_payment_match = re.search(r'(\d+([.,]\d+)*)\s*VND/month\s*for\s*(\d+)\s*months', amount, re.IGNORECASE)
    if monthly_payment_match:
        monthly_payment = monthly_payment_match.group(1).replace('.', '').replace(',', '')
        months = int(monthly_payment_match.group(3))
        return round(float(monthly_payment) * months)  # Return the total payment over the period
    
    # Handle ranges (e.g., "10.000.000-15.000.000")
    range_match = re.search(r'(\d+[.,\d]*)\s*[-đồng tođến]+\s*(\d+[.,\d]*)', amount, re.IGNORECASE)
    if range_match:
        low_amount = range_match.group(1).replace('.', '').replace(',', '')
        high_amount = range_match.group(2).replace('.', '').replace(',', '')
        # Convert to float and take the average of the range
        try:
            low_amount = float(low_amount)
            high_amount = float(high_amount)
            return round((low_amount + high_amount) / 2)
        except ValueError:
            return 0
        
    # Remove non-numeric characters but keep the decimal point and comma
    amount = re.sub(r'[^\d.,]', '', amount)
    # Determine if commas or periods are used as thousand separators or decimal points
    if ',' in amount and '.' in amount:
        if amount.find(',') < amount.find('.'):
            amount = amount.replace(',', '')
        else:
            amount = amount.replace('.', '')
            
    # Replace remaining commas with dots if they are used as decimal separators
    amount = amount.replace('.', ',')
    amount = amount.replace(',', '')
    # Convert to float and round to nearest integer (assuming no cents are needed)
    try:
        standardized_amount = eval(amount)
    except:
        standardized_amount = 0
    return standardized_amount

# Main function to process the DataFrame
def process_dataframe(df):
    # Apply the function to the birthdate column
    df.loc[:,'birthdate'] = df['birthdate'].apply(convert_to_standard_date)
    df.loc[:, 'standardized_jail_duration'] = df['jail_duration'].apply(convert_to_months)
    df.loc[:,'standardized_fine_total'] = df['fine_total'].apply(standardize_amount)
    df = filter_specific_strings(df)
    return df

def calculate_similarity(df, person):
    similarities_name = df['name'].apply(lambda x: fuzz.partial_ratio(person['name'], x))
    similarities_birthdate = df['birthdate'].apply(lambda x: fuzz.ratio(str(person['birthdate']), str(x)))
    similarities_province = df['province_name'].apply(lambda x: fuzz.ratio(person['province_name'], x))
    similarities_district = df['district_name'].apply(lambda x: fuzz.ratio(person['district_name'], x))
    similarities_village = df['village_name'].apply(lambda x:fuzz.ratio(person['village_name'], x))

    # Combine the similarities
    #total_similarity = similarities_name + similarities_birthdate + similarities_province + similarities_district + similarities_village
    total_similarity = similarities_name * 0.5 + similarities_birthdate * 0.1 + similarities_province * 0.2 + similarities_district * 0.1 + similarities_village * 0.1 

    # Combine the similarities and original DataFrame
    df['total_similarity'] = total_similarity

    # Retrieve the top 10 most similar rows
    top_10_rows = df.nlargest(10, 'total_similarity')  

    return top_10_rows

if __name__ == "__main__":
    # Load your DataFrame here
    df = read_bq()
    df = process_dataframe(df)
    person = {'name' : "Vũ Văn Hùng", 
              'birthdate' : "1985-11-10", 
              'province_name' : "Bình Dương", 
              'district_name' : "Thủ Dầu Một", 
              'village_name' : "Phú Cường"}
    
    top_10_rows = calculate_similarity(df, person)
    print(top_10_rows)
# Out:
#       extract_id                                           jlr_link      name  \
# 1816        3983  https://congbobanan.toaan.gov.vn/2ta854842t1cv...  Vũ Văn H
# 1045        4317  https://congbobanan.toaan.gov.vn/2ta66924t1cvn...  Vũ Văn H
# 508         6834  https://congbobanan.toaan.gov.vn/2ta1035760t1c...  Vũ Văn H
# 1047        4317  https://congbobanan.toaan.gov.vn/2ta66924t1cvn...  Vũ Văn M
# 9391          94  https://congbobanan.toaan.gov.vn/2ta566021t1cv...  Vũ Văn T
# 1268        4164  https://congbobanan.toaan.gov.vn/2ta258115t1cv...  Võ Văn L
# 590         6894  https://congbobanan.toaan.gov.vn/2ta823819t1cv...  Vũ Văn T
# 4130        6383  https://congbobanan.toaan.gov.vn/2ta203663t1cv...  Vũ Văn D
# 5654        5510  https://congbobanan.toaan.gov.vn/2ta1065710t1c...  Tạ Văn T
# 3957        6712  https://congbobanan.toaan.gov.vn/2ta910753t1cv...  Vũ Văn C
#
#        birthdate gender province_name district_name  \
# 1816  1989-04-25   Male    Bình Dương             P
# 1045  2000-10-15   Male     Hải Dương   Thành phố H
# 508   1994-12-04   Male     Thái Bình     Quỳnh Phụ
# 1047  1999-12-09   Male     Hải Dương          tp H
# 9391  1980-10-04   Male     Hải Dương             C
# 1268  1995-01-30   Male    Bình Dương             D
# 590   1996-11-30   Male     Hải Dương             T
# 4130  1991-01-10   Male     Hải Dương             T
# 5654  1968-10-20   Male    Bình Dương      Thuận An
# 3957  1983-09-02   Male     Hải Phòng        quận N
#
#                                  village_name  \
# 1816                                       AT
# 1045                               Đinh Văn T
# 508                                   Tân Dân
# 1047                                Vũ Khâm L
# 9391                          khu dân cư số 8
# 1268                                        A
# 590                                         T
# 4130                                       Np
# 5654  số nhà 3/15C, tổ 3, khu phố B, phường B
# 3957                                 phường L
#
#                                            full_address  \
# 1816             Ấp TB, xã AT, huyện P, tỉnh Bình Dương
# 1045  số 22/88 Đinh Văn T, phường B, Thành phố H, tỉ...
# 508   Thôn Tân Dân, xã Quỳnh Hưng, huyện Quỳnh Phụ, ...
# 1047      351 Vũ Khâm L, phường H, tp H, tỉnh Hải Dương
# 9391  khu dân cư số 8, phường P, thành phố C, tỉnh H...
# 1268               Ấp A, xã C, huyện D, tỉnh Bình Dương
# 590               Thôn T, xã C, huyện T, tỉnh Hải Dương
# 4130                     Thôn A, xã Np, huyện T, tỉnh H
# 5654  số nhà 3/15C, tổ 3, khu phố B, phường B, thành...
# 3957  Số 8/214 đường L, phường L, quận N, thành phố ...
#
#                                        crime jail    jail_duration fine  \
# 1816                     Possession of Drugs  yes  1 year 3 months   no
# 1045                                   Theft   no               no   no
# 508   Illegal Possession of Military Weapons  yes          5 years   no
# 1047                                   Theft   no               no   no
# 9391                                Gambling  yes         8 months  yes
# 1268                                Drug use   no               no   no
# 590              Illegal Possession of Drugs  yes        15 months   no
# 4130                                Gambling   no               no   no
# 5654                                Gambling   no               no  yes
# 3957                                   Theft  yes        18 months   no
#
#       fine_total                                   other_punishment  \
# 1816          no                                                 no
# 1045          no                  10 months of non-custodial reform
# 508           no                                                 no
# 1047          no                   8 months of non-custodial reform
# 9391  10,000,000                                                 no
# 1268          no  Forced drug rehabilitation for 14 months at Cơ...
# 590           no                                                 no
# 4130          no                              9 months of probation
# 5654  20.000.000                                                 no
# 3957          no                                                 no
#
#                           time standardized_jail_duration  \
# 1816 2024-05-28 15:59:33+00:00                         15
# 1045 2024-05-28 16:49:55+00:00             Not Applicable
# 508  2024-05-30 13:46:18+00:00                         60
# 1047 2024-05-28 16:49:55+00:00             Not Applicable
# 9391 2024-05-23 16:04:40+00:00                          8
# 1268 2024-05-28 16:27:27+00:00             Not Applicable
# 590  2024-05-30 14:07:54+00:00                         15
# 4130 2024-05-29 20:12:18+00:00             Not Applicable
# 5654 2024-05-29 14:26:51+00:00             Not Applicable
# 3957 2024-05-30 10:09:19+00:00                         18
#
#       standardized_fine_total  total_similarity
# 1816                        0         75.000000
# 1045                        0         73.425837
# 508                         0         68.921053
# 1047                        0         68.853801
# 9391                 10000000         68.798246
# 1268                        0         68.666667
# 590                         0         67.964912
# 4130                        0         67.964912
# 5654                 20000000         67.460526
# 3957                        0         67.217750

# %%
import requests
import subprocess
import json
# Obtain the identity token using gcloud
result = subprocess.run(['gcloud', 'auth', 'print-identity-token'], stdout=subprocess.PIPE)
identity_token = result.stdout.decode('utf-8').strip()

# URL to which the POST request will be sent
url = "https://us-central1-intern-project-415606.cloudfunctions.net/comparison"

# Data to be sent in the POST request
data = {
    "person": {
        "name": "Nguyễn Thị Minh",
        "birthdate": "1990-03-22",
        "province_name": "Hà Nội",
        "district_name": "Hoàn Kiếm",
        "village_name": "Hàng Đào"
    }
}


# Headers including the Authorization token
headers = {
    "Authorization": f"bearer {identity_token}",
    "Content-Type": "application/json"
}

# Send the POST request
response = requests.post(url, json=data, headers=headers)

# Decode the JSON response to make it readable
decoded_response = response.json()

# Pretty print the JSON response
print(json.dumps(decoded_response, ensure_ascii=False, indent=4))
# Out:
# [
#     {
#         "extract_id": 6822,
#         "jlr_link": "https://congbobanan.toaan.gov.vn/2ta921077t1cvn/chi-tiet-ban-an",
#         "name": "Nguyễn Thị N",
#         "birthdate": "1986-10-14",
#         "gender": "Female",
#         "province_name": "Hà Nội",
#         "district_name": "Tây Hồ",
#         "village_name": "Yên Phụ",
#         "full_address": "Ngõ 128, phố Yên Phụ, phường Yên Phụ, quận Tây Hồ, thành phố Hà Nội",
#         "crime": "Illegal possession of drugs",
#         "jail": "yes",
#         "jail_duration": "1 years 6 months 0 days",
#         "fine": "no",
#         "fine_total": "no",
#         "other_punishment": "no",
#         "time": 1717076521000,
#         "standardized_jail_duration": 18,
#         "standardized_fine_total": 0,
#         "total_similarity": 76.8260869565
#     },
#     {
#         "extract_id": 1025,
#         "jlr_link": "https://congbobanan.toaan.gov.vn/2ta735413t1cvn/chi-tiet-ban-an",
#         "name": "Nguyễn Thị L",
#         "birthdate": "2004-10-10",
#         "gender": "Female",
#         "province_name": "Hà Nội",
#         "district_name": "Ba Vì",
#         "village_name": "xã Vạn Thắng",
#         "full_address": "xã Vạn Thắng, huyện Ba Vì, thành phố Hà Nội",
#         "crime": "Theft",
#         "jail": "no",
#         "jail_duration": "no",
#         "fine": "no",
#         "fine_total": "no",
#         "other_punishment": "no",
#         "time": 1716499588000,
#         "standardized_jail_duration": "Not Applicable",
#         "standardized_fine_total": 0,
#         "total_similarity": 75.2546583851
#     },
#     {
#         "extract_id": 5565,
#         "jlr_link": "https://congbobanan.toaan.gov.vn/2ta992141t1cvn/chi-tiet-ban-an",
#         "name": "Nguyễn Thị Thùy L",
#         "birthdate": "1994-10-14",
#         "gender": "Female",
#         "province_name": "Hà Nội",
#         "district_name": "quận I",
#         "village_name": "tổ dân phố N",
#         "full_address": "Số 1, ngách 266/8, ngõ 266, tổ dân phố N, phường U, quận I, thành phố Hà Nội",
#         "crime": "Fraudulent appropriation of property",
#         "jail": "yes",
#         "jail_duration": "3 years",
#         "fine": "no",
#         "fine_total": "no",
#         "other_punishment": "no",
#         "time": 1716993892000,
#         "standardized_jail_duration": 36,
#         "standardized_fine_total": 0,
#         "total_similarity": 73.5238095238
#     },
#     {
#         "extract_id": 1782,
#         "jlr_link": "https://congbobanan.toaan.gov.vn/2ta913473t1cvn/chi-tiet-ban-an",
#         "name": "Nguyễn Thu U",
#         "birthdate": "2000-05-02",
#         "gender": "Female",
#         "province_name": "Hà Nội",
#         "district_name": "Hai Bà Trưng",
#         "village_name": "Thanh Lương",
#         "full_address": "phường Thanh Lương, quận Hai Bà Trưng, thành phố Hà Nội",
#         "crime": "Mua bán trái phép chất ma túy",
#         "jail": "yes",
#         "jail_duration": "36",
#         "fine": "no",
#         "fine_total": "no",
#         "other_punishment": "Tịch thu, tiêu hủy: Ma túy và một sim điện thoại di động.\nTịch thu, sung quỹ Nhà nước: Điện thoại di động nhãn hiệu Iphone 6 màu bạc của bị cáo Nguyễn Ngọc Q dùng liên lạc mua bán ma túy.\nMỗi bị cáo phải nộp 225.000 đồng để tịch thu sung quỹ Nhà nước.",
#         "time": 1716739235000,
#         "standardized_jail_duration": 0,
#         "standardized_fine_total": 0,
#         "total_similarity": 73.4406668846
#     },
#     {
#         "extract_id": 1580,
#         "jlr_link": "https://congbobanan.toaan.gov.vn/2ta590805t1cvn/chi-tiet-ban-an",
#         "name": "Nguyễn Thị Hòa",
#         "birthdate": "1966-10-04",
#         "gender": "Female",
#         "province_name": "Hà Nội",
#         "district_name": "Chương Mỹ",
#         "village_name": "Tổ 4",
#         "full_address": "Tổ 4, khu Tân Bình, Thị trấn S, Chương Mỹ, Hà Nội",
#         "crime": "Gambling",
#         "jail": "yes",
#         "jail_duration": "3 years",
#         "fine": "no",
#         "fine_total": "no",
#         "other_punishment": "no",
#         "time": 1716607336000,
#         "standardized_jail_duration": 36,
#         "standardized_fine_total": 0,
#         "total_similarity": 72.8888888889
#     }
# ]
