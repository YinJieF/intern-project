# %% [markdown]
# # INSTALL REQUIRED PACKAGE

# %%
! pip3 install --quiet --upgrade pandas-gbq 'google-cloud-bigquery[bqstorage,pandas]' scikit-learn
# %pip install underthesea
# Out:
# Requirement already satisfied: underthesea in /opt/conda/lib/python3.10/site-packages (6.8.0)
# Requirement already satisfied: Click>=6.0 in /opt/conda/lib/python3.10/site-packages (from underthesea) (8.1.7)
# Requirement already satisfied: python-crfsuite>=0.9.6 in /opt/conda/lib/python3.10/site-packages (from underthesea) (0.9.10)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from underthesea) (3.8.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from underthesea) (4.66.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from underthesea) (2.31.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.3.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.4.1.post1)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from underthesea) (6.0.1)
# Requirement already satisfied: underthesea-core==1.0.4 in /opt/conda/lib/python3.10/site-packages (from underthesea) (1.0.4)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/lib/python3.10/site-packages (from nltk->underthesea) (2023.12.25)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->underthesea) (2024.2.2)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (1.25.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (1.11.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->underthesea) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Set project id

# %%
PROJECT_ID = "intern-project-415606"  # @param {type:"string"}

# set the project id
! gcloud config set project $PROJECT_ID
# Out:
# Updated property [core/project].

# %% [markdown]
# ## Load data from bigquery

# %%
from google.cloud import bigquery

# Create a BigQuery client
client = bigquery.Client()

# Define your BigQuery query to extract data
query = """
    SELECT *
    FROM intern-project-415606.Criminal_Dataset.criminal_data
"""

# Run the query and get the result
query_job = client.query(query)

# Convert the result into a Pandas DataFrame
df = query_job.to_dataframe()

# %%
df.head()
# Out:
#                                             JLR_LINK TRANS_TYPE_OF_CASE  \
# 0  https://congbobanan.toaan.gov.vn/2ta827827t1cv...        採取行政處理措施的決定
# 1  https://congbobanan.toaan.gov.vn/2ta889668t1cv...                 刑事
# 2  https://congbobanan.toaan.gov.vn/2ta153804t1cv...                 刑事
# 3  https://congbobanan.toaan.gov.vn/2ta1126341t1c...                 刑事
# 4  https://congbobanan.toaan.gov.vn/2ta1066372t1c...                 刑事
#
#   TRANS_LEGAL_RELATIONSHIP                                           PDF_TEXT  \
# 0                放入強制性戒毒機構  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
# 1                 犯罪非法持有毒品  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
# 2                    盜竊財產罪  <Page:1>TOÀ ÁN NHÂN DÂN CỘNG HOÀ XÃ HỘI CHỦ NG...
# 3                 犯罪非法持有毒品  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
# 4                  欺詐佔有財產罪  <Page:1>TÒA ÁN NHÂN DÂN CỘNG HÒA XÃ HỘI CHỦ NG...
#
#                                              EXTRACT     ID          NAME  \
# 0   Họ và tên: Nguyễn Văn C – Giới tính: Nam Sinh...  No_Id  Nguyễn Văn C
# 1   Họ và tên: Trần Ngọc T, sinh ngày 08/12/1993....  No_Id   Trần Ngọc T
# 2   Bùi Văn T, sinh ngày 09/12/1989 Tại: Xóm T – ...  No_Id     Bùi Văn T
# 3   Nguyễn Văn Đ, sinh ngày 04/8/1978 tại huyện H...  No_Id  Nguyễn Văn Đ
# 4   Cao Thị B, sinh ngày 01/01/1975, tại huyện C,...  No_Id     Cao Thị B
#
#    Year  Month  Day  GENDER                BIRTH
# 0  1994      1   25    Male  1994-01-25 00:00:00
# 1  1993     12    8    Male  1993-12-08 00:00:00
# 2  1989     12    9    Male  1989-12-09 00:00:00
# 3  1978      8    4    Male  1978-08-04 00:00:00
# 4  1975      1    1  Female  1975-01-01 00:00:00

# %% [markdown]
# ## Build Table

# %%
# Specify your Google Cloud Platform project ID
project_id = 'intern-project-415606'

# Specify the dataset ID
dataset_id = 'Criminal_Dataset'

# Specify the table ID
table_id = 'criminal_data_ner'

# Specify schema
schema = [
    bigquery.SchemaField("extract_id", "STRING", mode="REQUIRED"),
    bigquery.SchemaField("text", "STRING", mode="REQUIRED"),
    bigquery.SchemaField("ner_underthesea", "STRING", mode="REQUIRED"),
    bigquery.SchemaField("tag_underthesea", "STRING", mode="REQUIRED"),
    bigquery.SchemaField("self_label", "STRING", mode="REQUIRED")
]

# Create a BigQuery table
table = bigquery.Table(f"{project_id}.{dataset_id}.{table_id}", schema=schema)

# Send the table creation request to the BigQuery API
try:
    table = client.create_table(table)  # API request
    print(f"Table {table_id} created successfully.")
except Exception as e:
    print(f"Error creating table: {e}")
# Out:
# Table criminal_data_ner created successfully.

# %% [markdown]
# ## NER, and label name

# %%
from underthesea import ner
# Specify your Google Cloud Platform project ID
project_id = 'intern-project-415606'

# Specify the dataset ID
dataset_id = 'Criminal_Dataset'

# Specify the table ID
table_id = 'criminal_data_ner'
# carry out ner and insert into bigquery
for i in range(0, 1000):
    ner_result = ner(df['EXTRACT'][i])

    rows = []
    for entity in ner_result:
        row = {
            "extract_id": str(i),  # You can use the index 'i' as the ID for each sentence
            "text": entity[0],
            "ner_underthesea": entity[3],
            "tag_underthesea": entity[1],
            "self_label": 'other'
        }
        # self label provided name as N
        if df['NAME'][i].strip() == row['text'].strip():
            row['self_label'] = 'N'
        # self label numeric data as M
        elif row['tag_underthesea'] == 'M' or row['text'].count('/') == 2:
            row['self_label'] = 'M'
        rows.append(row)
        
    # for row in rows:
    #     print(row)
    # Insert each row into BigQuery
    errors = client.insert_rows_json(f"{project_id}.{dataset_id}.{table_id}", rows)

    if errors == []:
        print(f"Inserted successfully for sentence {i}.")
    else:
        print(f"Errors encountered while inserting rows for sentence {i}: {errors}")
# Out:
# Inserted successfully for sentence 0.
# Inserted successfully for sentence 1.
# Inserted successfully for sentence 2.
# Inserted successfully for sentence 3.
# Inserted successfully for sentence 4.
# Inserted successfully for sentence 5.
# Inserted successfully for sentence 6.
# Inserted successfully for sentence 7.
# Inserted successfully for sentence 8.
# Inserted successfully for sentence 9.
# Inserted successfully for sentence 10.
# Inserted successfully for sentence 11.
# Inserted successfully for sentence 12.
# Inserted successfully for sentence 13.
# Inserted successfully for sentence 14.
# Inserted successfully for sentence 15.
# Inserted successfully for sentence 16.
# Inserted successfully for sentence 17.
# Inserted successfully for sentence 18.
# Inserted successfully for sentence 19.
# Inserted successfully for sentence 20.
# Inserted successfully for sentence 21.
# Inserted successfully for sentence 22.
# Inserted successfully for sentence 23.
# Inserted successfully for sentence 24.
# Inserted successfully for sentence 25.
# Inserted successfully for sentence 26.
# Inserted successfully for sentence 27.
# Inserted successfully for sentence 28.
# Inserted successfully for sentence 29.
# Inserted successfully for sentence 30.
# Inserted successfully for sentence 31.
# Inserted successfully for sentence 32.
# Inserted successfully for sentence 33.
# Inserted successfully for sentence 34.
# Inserted successfully for sentence 35.
# Inserted successfully for sentence 36.
# Inserted successfully for sentence 37.
# Inserted successfully for sentence 38.
# Inserted successfully for sentence 39.
# Inserted successfully for sentence 40.
# Inserted successfully for sentence 41.
# Inserted successfully for sentence 42.
# Inserted successfully for sentence 43.
# Inserted successfully for sentence 44.
# Inserted successfully for sentence 45.
# Inserted successfully for sentence 46.
# Inserted successfully for sentence 47.
# Inserted successfully for sentence 48.
# Inserted successfully for sentence 49.
# Inserted successfully for sentence 50.
# Inserted successfully for sentence 51.
# Inserted successfully for sentence 52.
# Inserted successfully for sentence 53.
# Inserted successfully for sentence 54.
# Inserted successfully for sentence 55.
# Inserted successfully for sentence 56.
# Inserted successfully for sentence 57.
# Inserted successfully for sentence 58.
# Inserted successfully for sentence 59.
# Inserted successfully for sentence 60.
# Inserted successfully for sentence 61.
# Inserted successfully for sentence 62.
# Inserted successfully for sentence 63.
# Inserted successfully for sentence 64.
# Inserted successfully for sentence 65.
# Inserted successfully for sentence 66.
# Inserted successfully for sentence 67.
# Inserted successfully for sentence 68.
# Inserted successfully for sentence 69.
# Inserted successfully for sentence 70.
# Inserted successfully for sentence 71.
# Inserted successfully for sentence 72.
# Inserted successfully for sentence 73.
# Inserted successfully for sentence 74.
# Inserted successfully for sentence 75.
# Inserted successfully for sentence 76.
# Inserted successfully for sentence 77.
# Inserted successfully for sentence 78.
# Inserted successfully for sentence 79.
# Inserted successfully for sentence 80.
# Inserted successfully for sentence 81.
# Inserted successfully for sentence 82.
# Inserted successfully for sentence 83.
# Inserted successfully for sentence 84.
# Inserted successfully for sentence 85.
# Inserted successfully for sentence 86.
# Inserted successfully for sentence 87.
# Inserted successfully for sentence 88.
# Inserted successfully for sentence 89.
# Inserted successfully for sentence 90.
# Inserted successfully for sentence 91.
# Inserted successfully for sentence 92.
# Inserted successfully for sentence 93.
# Inserted successfully for sentence 94.
# Inserted successfully for sentence 95.
# Inserted successfully for sentence 96.
# Inserted successfully for sentence 97.
# Inserted successfully for sentence 98.
# Inserted successfully for sentence 99.
# Inserted successfully for sentence 100.
# Inserted successfully for sentence 101.
# Inserted successfully for sentence 102.
# Inserted successfully for sentence 103.
# Inserted successfully for sentence 104.
# Inserted successfully for sentence 105.
# Inserted successfully for sentence 106.
# Inserted successfully for sentence 107.
# Inserted successfully for sentence 108.
# Inserted successfully for sentence 109.
# Inserted successfully for sentence 110.
# Inserted successfully for sentence 111.
# Inserted successfully for sentence 112.
# Inserted successfully for sentence 113.
# Inserted successfully for sentence 114.
# Inserted successfully for sentence 115.
# Inserted successfully for sentence 116.
# Inserted successfully for sentence 117.
# Inserted successfully for sentence 118.
# Inserted successfully for sentence 119.
# Inserted successfully for sentence 120.
# Inserted successfully for sentence 121.
# Inserted successfully for sentence 122.
# Inserted successfully for sentence 123.
# Inserted successfully for sentence 124.
# Inserted successfully for sentence 125.
# Inserted successfully for sentence 126.
# Inserted successfully for sentence 127.
# Inserted successfully for sentence 128.
# Inserted successfully for sentence 129.
# Inserted successfully for sentence 130.
# Inserted successfully for sentence 131.
# Inserted successfully for sentence 132.
# Inserted successfully for sentence 133.
# Inserted successfully for sentence 134.
# Inserted successfully for sentence 135.
# Inserted successfully for sentence 136.
# Inserted successfully for sentence 137.
# Inserted successfully for sentence 138.
# Inserted successfully for sentence 139.
# Inserted successfully for sentence 140.
# Inserted successfully for sentence 141.
# Inserted successfully for sentence 142.
# Inserted successfully for sentence 143.
# Inserted successfully for sentence 144.
# Inserted successfully for sentence 145.
# Inserted successfully for sentence 146.
# Inserted successfully for sentence 147.
# Inserted successfully for sentence 148.
# Inserted successfully for sentence 149.
# Inserted successfully for sentence 150.
# Inserted successfully for sentence 151.
# Inserted successfully for sentence 152.
# Inserted successfully for sentence 153.
# Inserted successfully for sentence 154.
# Inserted successfully for sentence 155.
# Inserted successfully for sentence 156.
# Inserted successfully for sentence 157.
# Inserted successfully for sentence 158.
# Inserted successfully for sentence 159.
# Inserted successfully for sentence 160.
# Inserted successfully for sentence 161.
# Inserted successfully for sentence 162.
# Inserted successfully for sentence 163.
# Inserted successfully for sentence 164.
# Inserted successfully for sentence 165.
# Inserted successfully for sentence 166.
# Inserted successfully for sentence 167.
# Inserted successfully for sentence 168.
# Inserted successfully for sentence 169.
# Inserted successfully for sentence 170.
# Inserted successfully for sentence 171.
# Inserted successfully for sentence 172.
# Inserted successfully for sentence 173.
# Inserted successfully for sentence 174.
# Inserted successfully for sentence 175.
# Inserted successfully for sentence 176.
# Inserted successfully for sentence 177.
# Inserted successfully for sentence 178.
# Inserted successfully for sentence 179.
# Inserted successfully for sentence 180.
# Inserted successfully for sentence 181.
# Inserted successfully for sentence 182.
# Inserted successfully for sentence 183.
# Inserted successfully for sentence 184.
# Inserted successfully for sentence 185.
# Inserted successfully for sentence 186.
# Inserted successfully for sentence 187.
# Inserted successfully for sentence 188.
# Inserted successfully for sentence 189.
# Inserted successfully for sentence 190.
# Inserted successfully for sentence 191.
# Inserted successfully for sentence 192.
# Inserted successfully for sentence 193.
# Inserted successfully for sentence 194.
# Inserted successfully for sentence 195.
# Inserted successfully for sentence 196.
# Inserted successfully for sentence 197.
# Inserted successfully for sentence 198.
# Inserted successfully for sentence 199.
# Inserted successfully for sentence 200.
# Inserted successfully for sentence 201.
# Inserted successfully for sentence 202.
# Inserted successfully for sentence 203.
# Inserted successfully for sentence 204.
# Inserted successfully for sentence 205.
# Inserted successfully for sentence 206.
# Inserted successfully for sentence 207.
# Inserted successfully for sentence 208.
# Inserted successfully for sentence 209.
# Inserted successfully for sentence 210.
# Inserted successfully for sentence 211.
# Inserted successfully for sentence 212.
# Inserted successfully for sentence 213.
# Inserted successfully for sentence 214.
# Inserted successfully for sentence 215.
# Inserted successfully for sentence 216.
# Inserted successfully for sentence 217.
# Inserted successfully for sentence 218.
# Inserted successfully for sentence 219.
# Inserted successfully for sentence 220.
# Inserted successfully for sentence 221.
# Inserted successfully for sentence 222.
# Inserted successfully for sentence 223.
# Inserted successfully for sentence 224.
# Inserted successfully for sentence 225.
# Inserted successfully for sentence 226.
# Inserted successfully for sentence 227.
# Inserted successfully for sentence 228.
# Inserted successfully for sentence 229.
# Inserted successfully for sentence 230.
# Inserted successfully for sentence 231.
# Inserted successfully for sentence 232.
# Inserted successfully for sentence 233.
# Inserted successfully for sentence 234.
# Inserted successfully for sentence 235.
# Inserted successfully for sentence 236.
# Inserted successfully for sentence 237.
# Inserted successfully for sentence 238.
# Inserted successfully for sentence 239.
# Inserted successfully for sentence 240.
# Inserted successfully for sentence 241.
# Inserted successfully for sentence 242.
# Inserted successfully for sentence 243.
# Inserted successfully for sentence 244.
# Inserted successfully for sentence 245.
# Inserted successfully for sentence 246.
# Inserted successfully for sentence 247.
# Inserted successfully for sentence 248.
# Inserted successfully for sentence 249.
# Inserted successfully for sentence 250.
# Inserted successfully for sentence 251.
# Inserted successfully for sentence 252.
# Inserted successfully for sentence 253.
# Inserted successfully for sentence 254.
# Inserted successfully for sentence 255.
# Inserted successfully for sentence 256.
# Inserted successfully for sentence 257.
# Inserted successfully for sentence 258.
# Inserted successfully for sentence 259.
# Inserted successfully for sentence 260.
# Inserted successfully for sentence 261.
# Inserted successfully for sentence 262.
# Inserted successfully for sentence 263.
# Inserted successfully for sentence 264.
# Inserted successfully for sentence 265.
# Inserted successfully for sentence 266.
# Inserted successfully for sentence 267.
# Inserted successfully for sentence 268.
# Inserted successfully for sentence 269.
# Inserted successfully for sentence 270.
# Inserted successfully for sentence 271.
# Inserted successfully for sentence 272.
# Inserted successfully for sentence 273.
# Inserted successfully for sentence 274.
# Inserted successfully for sentence 275.
# Inserted successfully for sentence 276.
# Inserted successfully for sentence 277.
# Inserted successfully for sentence 278.
# Inserted successfully for sentence 279.
# Inserted successfully for sentence 280.
# Inserted successfully for sentence 281.
# Inserted successfully for sentence 282.
# Inserted successfully for sentence 283.
# Inserted successfully for sentence 284.
# Inserted successfully for sentence 285.
# Inserted successfully for sentence 286.
# Inserted successfully for sentence 287.
# Inserted successfully for sentence 288.
# Inserted successfully for sentence 289.
# Inserted successfully for sentence 290.
# Inserted successfully for sentence 291.
# Inserted successfully for sentence 292.
# Inserted successfully for sentence 293.
# Inserted successfully for sentence 294.
# Inserted successfully for sentence 295.
# Inserted successfully for sentence 296.
# Inserted successfully for sentence 297.
# Inserted successfully for sentence 298.
# Inserted successfully for sentence 299.
# Inserted successfully for sentence 300.
# Inserted successfully for sentence 301.
# Inserted successfully for sentence 302.
# Inserted successfully for sentence 303.
# Inserted successfully for sentence 304.
# Inserted successfully for sentence 305.
# Inserted successfully for sentence 306.
# Inserted successfully for sentence 307.
# Inserted successfully for sentence 308.
# Inserted successfully for sentence 309.
# Inserted successfully for sentence 310.
# Inserted successfully for sentence 311.
# Inserted successfully for sentence 312.
# Inserted successfully for sentence 313.
# Inserted successfully for sentence 314.
# Inserted successfully for sentence 315.
# Inserted successfully for sentence 316.
# Inserted successfully for sentence 317.
# Inserted successfully for sentence 318.
# Inserted successfully for sentence 319.
# Inserted successfully for sentence 320.
# Inserted successfully for sentence 321.
# Inserted successfully for sentence 322.
# Inserted successfully for sentence 323.
# Inserted successfully for sentence 324.
# Inserted successfully for sentence 325.
# Inserted successfully for sentence 326.
# Inserted successfully for sentence 327.
# Inserted successfully for sentence 328.
# Inserted successfully for sentence 329.
# Inserted successfully for sentence 330.
# Inserted successfully for sentence 331.
# Inserted successfully for sentence 332.
# Inserted successfully for sentence 333.
# Inserted successfully for sentence 334.
# Inserted successfully for sentence 335.
# Inserted successfully for sentence 336.
# Inserted successfully for sentence 337.
# Inserted successfully for sentence 338.
# Inserted successfully for sentence 339.
# Inserted successfully for sentence 340.
# Inserted successfully for sentence 341.
# Inserted successfully for sentence 342.
# Inserted successfully for sentence 343.
# Inserted successfully for sentence 344.
# Inserted successfully for sentence 345.
# Inserted successfully for sentence 346.
# Inserted successfully for sentence 347.
# Inserted successfully for sentence 348.
# Inserted successfully for sentence 349.
# Inserted successfully for sentence 350.
# Inserted successfully for sentence 351.
# Inserted successfully for sentence 352.
# Inserted successfully for sentence 353.
# Inserted successfully for sentence 354.
# Inserted successfully for sentence 355.
# Inserted successfully for sentence 356.
# Inserted successfully for sentence 357.
# Inserted successfully for sentence 358.
# Inserted successfully for sentence 359.
# Inserted successfully for sentence 360.
# Inserted successfully for sentence 361.
# Inserted successfully for sentence 362.
# Inserted successfully for sentence 363.
# Inserted successfully for sentence 364.
# Inserted successfully for sentence 365.
# Inserted successfully for sentence 366.
# Inserted successfully for sentence 367.
# Inserted successfully for sentence 368.
# Inserted successfully for sentence 369.
# Inserted successfully for sentence 370.
# Inserted successfully for sentence 371.
# Inserted successfully for sentence 372.
# Inserted successfully for sentence 373.
# Inserted successfully for sentence 374.
# Inserted successfully for sentence 375.
# Inserted successfully for sentence 376.
# Inserted successfully for sentence 377.
# Inserted successfully for sentence 378.
# Inserted successfully for sentence 379.
# Inserted successfully for sentence 380.
# Inserted successfully for sentence 381.
# Inserted successfully for sentence 382.
# Inserted successfully for sentence 383.
# Inserted successfully for sentence 384.
# Inserted successfully for sentence 385.
# Inserted successfully for sentence 386.
# Inserted successfully for sentence 387.
# Inserted successfully for sentence 388.
# Inserted successfully for sentence 389.
# Inserted successfully for sentence 390.
# Inserted successfully for sentence 391.
# Inserted successfully for sentence 392.
# Inserted successfully for sentence 393.
# Inserted successfully for sentence 394.
# Inserted successfully for sentence 395.
# Inserted successfully for sentence 396.
# Inserted successfully for sentence 397.
# Inserted successfully for sentence 398.
# Inserted successfully for sentence 399.
# Inserted successfully for sentence 400.
# Inserted successfully for sentence 401.
# Inserted successfully for sentence 402.
# Inserted successfully for sentence 403.
# Inserted successfully for sentence 404.
# Inserted successfully for sentence 405.
# Inserted successfully for sentence 406.
# Inserted successfully for sentence 407.
# Inserted successfully for sentence 408.
# Inserted successfully for sentence 409.
# Inserted successfully for sentence 410.
# Inserted successfully for sentence 411.
# Inserted successfully for sentence 412.
# Inserted successfully for sentence 413.
# Inserted successfully for sentence 414.
# Inserted successfully for sentence 415.
# Inserted successfully for sentence 416.
# Inserted successfully for sentence 417.
# Inserted successfully for sentence 418.
# Inserted successfully for sentence 419.
# Inserted successfully for sentence 420.
# Inserted successfully for sentence 421.
# Inserted successfully for sentence 422.
# Inserted successfully for sentence 423.
# Inserted successfully for sentence 424.
# Inserted successfully for sentence 425.
# Inserted successfully for sentence 426.
# Inserted successfully for sentence 427.
# Inserted successfully for sentence 428.
# Inserted successfully for sentence 429.
# Inserted successfully for sentence 430.
# Inserted successfully for sentence 431.
# Inserted successfully for sentence 432.
# Inserted successfully for sentence 433.
# Inserted successfully for sentence 434.
# Inserted successfully for sentence 435.
# Inserted successfully for sentence 436.
# Inserted successfully for sentence 437.
# Inserted successfully for sentence 438.
# Inserted successfully for sentence 439.
# Inserted successfully for sentence 440.
# Inserted successfully for sentence 441.
# Inserted successfully for sentence 442.
# Inserted successfully for sentence 443.
# Inserted successfully for sentence 444.
# Inserted successfully for sentence 445.
# Inserted successfully for sentence 446.
# Inserted successfully for sentence 447.
# Inserted successfully for sentence 448.
# Inserted successfully for sentence 449.
# Inserted successfully for sentence 450.
# Inserted successfully for sentence 451.
# Inserted successfully for sentence 452.
# Inserted successfully for sentence 453.
# Inserted successfully for sentence 454.
# Inserted successfully for sentence 455.
# Inserted successfully for sentence 456.
# Inserted successfully for sentence 457.
# Inserted successfully for sentence 458.
# Inserted successfully for sentence 459.
# Inserted successfully for sentence 460.
# Inserted successfully for sentence 461.
# Inserted successfully for sentence 462.
# Inserted successfully for sentence 463.
# Inserted successfully for sentence 464.
# Inserted successfully for sentence 465.
# Inserted successfully for sentence 466.
# Inserted successfully for sentence 467.
# Inserted successfully for sentence 468.
# Inserted successfully for sentence 469.
# Inserted successfully for sentence 470.
# Inserted successfully for sentence 471.
# Inserted successfully for sentence 472.
# Inserted successfully for sentence 473.
# Inserted successfully for sentence 474.
# Inserted successfully for sentence 475.
# Inserted successfully for sentence 476.
# Inserted successfully for sentence 477.
# Inserted successfully for sentence 478.
# Inserted successfully for sentence 479.
# Inserted successfully for sentence 480.
# Inserted successfully for sentence 481.
# Inserted successfully for sentence 482.
# Inserted successfully for sentence 483.
# Inserted successfully for sentence 484.
# Inserted successfully for sentence 485.
# Inserted successfully for sentence 486.
# Inserted successfully for sentence 487.
# Inserted successfully for sentence 488.
# Inserted successfully for sentence 489.
# Inserted successfully for sentence 490.
# Inserted successfully for sentence 491.
# Inserted successfully for sentence 492.
# Inserted successfully for sentence 493.
# Inserted successfully for sentence 494.
# Inserted successfully for sentence 495.
# Inserted successfully for sentence 496.
# Inserted successfully for sentence 497.
# Inserted successfully for sentence 498.
# Inserted successfully for sentence 499.
# Inserted successfully for sentence 500.
# Inserted successfully for sentence 501.
# Inserted successfully for sentence 502.
# Inserted successfully for sentence 503.
# Inserted successfully for sentence 504.
# Inserted successfully for sentence 505.
# Inserted successfully for sentence 506.
# Inserted successfully for sentence 507.
# Inserted successfully for sentence 508.
# Inserted successfully for sentence 509.
# Inserted successfully for sentence 510.
# Inserted successfully for sentence 511.
# Inserted successfully for sentence 512.
# Inserted successfully for sentence 513.
# Inserted successfully for sentence 514.
# Inserted successfully for sentence 515.
# Inserted successfully for sentence 516.
# Inserted successfully for sentence 517.
# Inserted successfully for sentence 518.
# Inserted successfully for sentence 519.
# Inserted successfully for sentence 520.
# Inserted successfully for sentence 521.
# Inserted successfully for sentence 522.
# Inserted successfully for sentence 523.
# Inserted successfully for sentence 524.
# Inserted successfully for sentence 525.
# Inserted successfully for sentence 526.
# Inserted successfully for sentence 527.
# Inserted successfully for sentence 528.
# Inserted successfully for sentence 529.
# Inserted successfully for sentence 530.
# Inserted successfully for sentence 531.
# Inserted successfully for sentence 532.
# Inserted successfully for sentence 533.
# Inserted successfully for sentence 534.
# Inserted successfully for sentence 535.
# Inserted successfully for sentence 536.
# Inserted successfully for sentence 537.
# Inserted successfully for sentence 538.
# Inserted successfully for sentence 539.
# Inserted successfully for sentence 540.
# Inserted successfully for sentence 541.
# Inserted successfully for sentence 542.
# Inserted successfully for sentence 543.
# Inserted successfully for sentence 544.
# Inserted successfully for sentence 545.
# Inserted successfully for sentence 546.
# Inserted successfully for sentence 547.
# Inserted successfully for sentence 548.
# Inserted successfully for sentence 549.
# Inserted successfully for sentence 550.
# Inserted successfully for sentence 551.
# Inserted successfully for sentence 552.
# Inserted successfully for sentence 553.
# Inserted successfully for sentence 554.
# Inserted successfully for sentence 555.
# Inserted successfully for sentence 556.
# Inserted successfully for sentence 557.
# Inserted successfully for sentence 558.
# Inserted successfully for sentence 559.
# Inserted successfully for sentence 560.
# Inserted successfully for sentence 561.
# Inserted successfully for sentence 562.
# Inserted successfully for sentence 563.
# Inserted successfully for sentence 564.
# Inserted successfully for sentence 565.
# Inserted successfully for sentence 566.
# Inserted successfully for sentence 567.
# Inserted successfully for sentence 568.
# Inserted successfully for sentence 569.
# Inserted successfully for sentence 570.
# Inserted successfully for sentence 571.
# Inserted successfully for sentence 572.
# Inserted successfully for sentence 573.
# Inserted successfully for sentence 574.
# Inserted successfully for sentence 575.
# Inserted successfully for sentence 576.
# Inserted successfully for sentence 577.
# Inserted successfully for sentence 578.
# Inserted successfully for sentence 579.
# Inserted successfully for sentence 580.
# Inserted successfully for sentence 581.
# Inserted successfully for sentence 582.
# Inserted successfully for sentence 583.
# Inserted successfully for sentence 584.
# Inserted successfully for sentence 585.
# Inserted successfully for sentence 586.
# Inserted successfully for sentence 587.
# Inserted successfully for sentence 588.
# Inserted successfully for sentence 589.
# Inserted successfully for sentence 590.
# Inserted successfully for sentence 591.
# Inserted successfully for sentence 592.
# Inserted successfully for sentence 593.
# Inserted successfully for sentence 594.
# Inserted successfully for sentence 595.
# Inserted successfully for sentence 596.
# Inserted successfully for sentence 597.
# Inserted successfully for sentence 598.
# Inserted successfully for sentence 599.
# Inserted successfully for sentence 600.
# Inserted successfully for sentence 601.
# Inserted successfully for sentence 602.
# Inserted successfully for sentence 603.
# Inserted successfully for sentence 604.
# Inserted successfully for sentence 605.
# Inserted successfully for sentence 606.
# Inserted successfully for sentence 607.
# Inserted successfully for sentence 608.
# Inserted successfully for sentence 609.
# Inserted successfully for sentence 610.
# Inserted successfully for sentence 611.
# Inserted successfully for sentence 612.
# Inserted successfully for sentence 613.
# Inserted successfully for sentence 614.
# Inserted successfully for sentence 615.
# Inserted successfully for sentence 616.
# Inserted successfully for sentence 617.
# Inserted successfully for sentence 618.
# Inserted successfully for sentence 619.
# Inserted successfully for sentence 620.
# Inserted successfully for sentence 621.
# Inserted successfully for sentence 622.
# Inserted successfully for sentence 623.
# Inserted successfully for sentence 624.
# Inserted successfully for sentence 625.
# Inserted successfully for sentence 626.
# Inserted successfully for sentence 627.
# Inserted successfully for sentence 628.
# Inserted successfully for sentence 629.
# Inserted successfully for sentence 630.
# Inserted successfully for sentence 631.
# Inserted successfully for sentence 632.
# Inserted successfully for sentence 633.
# Inserted successfully for sentence 634.
# Inserted successfully for sentence 635.
# Inserted successfully for sentence 636.
# Inserted successfully for sentence 637.
# Inserted successfully for sentence 638.
# Inserted successfully for sentence 639.
# Inserted successfully for sentence 640.
# Inserted successfully for sentence 641.
# Inserted successfully for sentence 642.
# Inserted successfully for sentence 643.
# Inserted successfully for sentence 644.
# Inserted successfully for sentence 645.
# Inserted successfully for sentence 646.
# Inserted successfully for sentence 647.
# Inserted successfully for sentence 648.
# Inserted successfully for sentence 649.
# Inserted successfully for sentence 650.
# Inserted successfully for sentence 651.
# Inserted successfully for sentence 652.
# Inserted successfully for sentence 653.
# Inserted successfully for sentence 654.
# Inserted successfully for sentence 655.
# Inserted successfully for sentence 656.
# Inserted successfully for sentence 657.
# Inserted successfully for sentence 658.
# Inserted successfully for sentence 659.
# Inserted successfully for sentence 660.
# Inserted successfully for sentence 661.
# Inserted successfully for sentence 662.
# Inserted successfully for sentence 663.
# Inserted successfully for sentence 664.
# Inserted successfully for sentence 665.
# Inserted successfully for sentence 666.
# Inserted successfully for sentence 667.
# Inserted successfully for sentence 668.
# Inserted successfully for sentence 669.
# Inserted successfully for sentence 670.
# Inserted successfully for sentence 671.
# Inserted successfully for sentence 672.
# Inserted successfully for sentence 673.
# Inserted successfully for sentence 674.
# Inserted successfully for sentence 675.
# Inserted successfully for sentence 676.
# Inserted successfully for sentence 677.
# Inserted successfully for sentence 678.
# Inserted successfully for sentence 679.
# Inserted successfully for sentence 680.
# Inserted successfully for sentence 681.
# Inserted successfully for sentence 682.
# Inserted successfully for sentence 683.
# Inserted successfully for sentence 684.
# Inserted successfully for sentence 685.
# Inserted successfully for sentence 686.
# Inserted successfully for sentence 687.
# Inserted successfully for sentence 688.
# Inserted successfully for sentence 689.
# Inserted successfully for sentence 690.
# Inserted successfully for sentence 691.
# Inserted successfully for sentence 692.
# Inserted successfully for sentence 693.
# Inserted successfully for sentence 694.
# Inserted successfully for sentence 695.
# Inserted successfully for sentence 696.
# Inserted successfully for sentence 697.
# Inserted successfully for sentence 698.
# Inserted successfully for sentence 699.
# Inserted successfully for sentence 700.
# Inserted successfully for sentence 701.
# Inserted successfully for sentence 702.
# Inserted successfully for sentence 703.
# Inserted successfully for sentence 704.
# Inserted successfully for sentence 705.
# Inserted successfully for sentence 706.
# Inserted successfully for sentence 707.
# Inserted successfully for sentence 708.
# Inserted successfully for sentence 709.
# Inserted successfully for sentence 710.
# Inserted successfully for sentence 711.
# Inserted successfully for sentence 712.
# Inserted successfully for sentence 713.
# Inserted successfully for sentence 714.
# Inserted successfully for sentence 715.
# Inserted successfully for sentence 716.
# Inserted successfully for sentence 717.
# Inserted successfully for sentence 718.
# Inserted successfully for sentence 719.
# Inserted successfully for sentence 720.
# Inserted successfully for sentence 721.
# Inserted successfully for sentence 722.
# Inserted successfully for sentence 723.
# Inserted successfully for sentence 724.
# Inserted successfully for sentence 725.
# Inserted successfully for sentence 726.
# Inserted successfully for sentence 727.
# Inserted successfully for sentence 728.
# Inserted successfully for sentence 729.
# Inserted successfully for sentence 730.
# Inserted successfully for sentence 731.
# Inserted successfully for sentence 732.
# Inserted successfully for sentence 733.
# Inserted successfully for sentence 734.
# Inserted successfully for sentence 735.
# Inserted successfully for sentence 736.
# Inserted successfully for sentence 737.
# Inserted successfully for sentence 738.
# Inserted successfully for sentence 739.
# Inserted successfully for sentence 740.
# Inserted successfully for sentence 741.
# Inserted successfully for sentence 742.
# Inserted successfully for sentence 743.
# Inserted successfully for sentence 744.
# Inserted successfully for sentence 745.
# Inserted successfully for sentence 746.
# Inserted successfully for sentence 747.
# Inserted successfully for sentence 748.
# Inserted successfully for sentence 749.
# Inserted successfully for sentence 750.
# Inserted successfully for sentence 751.
# Inserted successfully for sentence 752.
# Inserted successfully for sentence 753.
# Inserted successfully for sentence 754.
# Inserted successfully for sentence 755.
# Inserted successfully for sentence 756.
# Inserted successfully for sentence 757.
# Inserted successfully for sentence 758.
# Inserted successfully for sentence 759.
# Inserted successfully for sentence 760.
# Inserted successfully for sentence 761.
# Inserted successfully for sentence 762.
# Inserted successfully for sentence 763.
# Inserted successfully for sentence 764.
# Inserted successfully for sentence 765.
# Inserted successfully for sentence 766.
# Inserted successfully for sentence 767.
# Inserted successfully for sentence 768.
# Inserted successfully for sentence 769.
# Inserted successfully for sentence 770.
# Inserted successfully for sentence 771.
# Inserted successfully for sentence 772.
# Inserted successfully for sentence 773.
# Inserted successfully for sentence 774.
# Inserted successfully for sentence 775.
# Inserted successfully for sentence 776.
# Inserted successfully for sentence 777.
# Inserted successfully for sentence 778.
# Inserted successfully for sentence 779.
# Inserted successfully for sentence 780.
# Inserted successfully for sentence 781.
# Inserted successfully for sentence 782.
# Inserted successfully for sentence 783.
# Inserted successfully for sentence 784.
# Inserted successfully for sentence 785.
# Inserted successfully for sentence 786.
# Inserted successfully for sentence 787.
# Inserted successfully for sentence 788.
# Inserted successfully for sentence 789.
# Inserted successfully for sentence 790.
# Inserted successfully for sentence 791.
# Inserted successfully for sentence 792.
# Inserted successfully for sentence 793.
# Inserted successfully for sentence 794.
# Inserted successfully for sentence 795.
# Inserted successfully for sentence 796.
# Inserted successfully for sentence 797.
# Inserted successfully for sentence 798.
# Inserted successfully for sentence 799.
# Inserted successfully for sentence 800.
# Inserted successfully for sentence 801.
# Inserted successfully for sentence 802.
# Inserted successfully for sentence 803.
# Inserted successfully for sentence 804.
# Inserted successfully for sentence 805.
# Inserted successfully for sentence 806.
# Inserted successfully for sentence 807.
# Inserted successfully for sentence 808.
# Inserted successfully for sentence 809.
# Inserted successfully for sentence 810.
# Inserted successfully for sentence 811.
# Inserted successfully for sentence 812.
# Inserted successfully for sentence 813.
# Inserted successfully for sentence 814.
# Inserted successfully for sentence 815.
# Inserted successfully for sentence 816.
# Inserted successfully for sentence 817.
# Inserted successfully for sentence 818.
# Inserted successfully for sentence 819.
# Inserted successfully for sentence 820.
# Inserted successfully for sentence 821.
# Inserted successfully for sentence 822.
# Inserted successfully for sentence 823.
# Inserted successfully for sentence 824.
# Inserted successfully for sentence 825.
# Inserted successfully for sentence 826.
# Inserted successfully for sentence 827.
# Inserted successfully for sentence 828.
# Inserted successfully for sentence 829.
# Inserted successfully for sentence 830.
# Inserted successfully for sentence 831.
# Inserted successfully for sentence 832.
# Inserted successfully for sentence 833.
# Inserted successfully for sentence 834.
# Inserted successfully for sentence 835.
# Inserted successfully for sentence 836.
# Inserted successfully for sentence 837.
# Inserted successfully for sentence 838.
# Inserted successfully for sentence 839.
# Inserted successfully for sentence 840.
# Inserted successfully for sentence 841.
# Inserted successfully for sentence 842.
# Inserted successfully for sentence 843.
# Inserted successfully for sentence 844.
# Inserted successfully for sentence 845.
# Inserted successfully for sentence 846.
# Inserted successfully for sentence 847.
# Inserted successfully for sentence 848.
# Inserted successfully for sentence 849.
# Inserted successfully for sentence 850.
# Inserted successfully for sentence 851.
# Inserted successfully for sentence 852.
# Inserted successfully for sentence 853.
# Inserted successfully for sentence 854.
# Inserted successfully for sentence 855.
# Inserted successfully for sentence 856.
# Inserted successfully for sentence 857.
# Inserted successfully for sentence 858.
# Inserted successfully for sentence 859.
# Inserted successfully for sentence 860.
# Inserted successfully for sentence 861.
# Inserted successfully for sentence 862.
# Inserted successfully for sentence 863.
# Inserted successfully for sentence 864.
# Inserted successfully for sentence 865.
# Inserted successfully for sentence 866.
# Inserted successfully for sentence 867.
# Inserted successfully for sentence 868.
# Inserted successfully for sentence 869.
# Inserted successfully for sentence 870.
# Inserted successfully for sentence 871.
# Inserted successfully for sentence 872.
# Inserted successfully for sentence 873.
# Inserted successfully for sentence 874.
# Inserted successfully for sentence 875.
# Inserted successfully for sentence 876.
# Inserted successfully for sentence 877.
# Inserted successfully for sentence 878.
# Inserted successfully for sentence 879.
# Inserted successfully for sentence 880.
# Inserted successfully for sentence 881.
# Inserted successfully for sentence 882.
# Inserted successfully for sentence 883.
# Inserted successfully for sentence 884.
# Inserted successfully for sentence 885.
# Inserted successfully for sentence 886.
# Inserted successfully for sentence 887.
# Inserted successfully for sentence 888.
# Inserted successfully for sentence 889.
# Inserted successfully for sentence 890.
# Inserted successfully for sentence 891.
# Inserted successfully for sentence 892.
# Inserted successfully for sentence 893.
# Inserted successfully for sentence 894.
# Inserted successfully for sentence 895.
# Inserted successfully for sentence 896.
# Inserted successfully for sentence 897.
# Inserted successfully for sentence 898.
# Inserted successfully for sentence 899.
# Inserted successfully for sentence 900.
# Inserted successfully for sentence 901.
# Inserted successfully for sentence 902.
# Inserted successfully for sentence 903.
# Inserted successfully for sentence 904.
# Inserted successfully for sentence 905.
# Inserted successfully for sentence 906.
# Inserted successfully for sentence 907.
# Inserted successfully for sentence 908.
# Inserted successfully for sentence 909.
# Inserted successfully for sentence 910.
# Inserted successfully for sentence 911.
# Inserted successfully for sentence 912.
# Inserted successfully for sentence 913.
# Inserted successfully for sentence 914.
# Inserted successfully for sentence 915.
# Inserted successfully for sentence 916.
# Inserted successfully for sentence 917.
# Inserted successfully for sentence 918.
# Inserted successfully for sentence 919.
# Inserted successfully for sentence 920.
# Inserted successfully for sentence 921.
# Inserted successfully for sentence 922.
# Inserted successfully for sentence 923.
# Inserted successfully for sentence 924.
# Inserted successfully for sentence 925.
# Inserted successfully for sentence 926.
# Inserted successfully for sentence 927.
# Inserted successfully for sentence 928.
# Inserted successfully for sentence 929.
# Inserted successfully for sentence 930.
# Inserted successfully for sentence 931.
# Inserted successfully for sentence 932.
# Inserted successfully for sentence 933.
# Inserted successfully for sentence 934.
# Inserted successfully for sentence 935.
# Inserted successfully for sentence 936.
# Inserted successfully for sentence 937.
# Inserted successfully for sentence 938.
# Inserted successfully for sentence 939.
# Inserted successfully for sentence 940.
# Inserted successfully for sentence 941.
# Inserted successfully for sentence 942.
# Inserted successfully for sentence 943.
# Inserted successfully for sentence 944.
# Inserted successfully for sentence 945.
# Inserted successfully for sentence 946.
# Inserted successfully for sentence 947.
# Inserted successfully for sentence 948.
# Inserted successfully for sentence 949.
# Inserted successfully for sentence 950.
# Inserted successfully for sentence 951.
# Inserted successfully for sentence 952.
# Inserted successfully for sentence 953.
# Inserted successfully for sentence 954.
# Inserted successfully for sentence 955.
# Inserted successfully for sentence 956.
# Inserted successfully for sentence 957.
# Inserted successfully for sentence 958.
# Inserted successfully for sentence 959.
# Inserted successfully for sentence 960.
# Inserted successfully for sentence 961.
# Inserted successfully for sentence 962.
# Inserted successfully for sentence 963.
# Inserted successfully for sentence 964.
# Inserted successfully for sentence 965.
# Inserted successfully for sentence 966.
# Inserted successfully for sentence 967.
# Inserted successfully for sentence 968.
# Inserted successfully for sentence 969.
# Inserted successfully for sentence 970.
# Inserted successfully for sentence 971.
# Inserted successfully for sentence 972.
# Inserted successfully for sentence 973.
# Inserted successfully for sentence 974.
# Inserted successfully for sentence 975.
# Inserted successfully for sentence 976.
# Inserted successfully for sentence 977.
# Inserted successfully for sentence 978.
# Inserted successfully for sentence 979.
# Inserted successfully for sentence 980.
# Inserted successfully for sentence 981.
# Inserted successfully for sentence 982.
# Inserted successfully for sentence 983.
# Inserted successfully for sentence 984.
# Inserted successfully for sentence 985.
# Inserted successfully for sentence 986.
# Inserted successfully for sentence 987.
# Inserted successfully for sentence 988.
# Inserted successfully for sentence 989.
# Inserted successfully for sentence 990.
# Inserted successfully for sentence 991.
# Inserted successfully for sentence 992.
# Inserted successfully for sentence 993.
# Inserted successfully for sentence 994.
# Inserted successfully for sentence 995.
# Inserted successfully for sentence 996.
# Inserted successfully for sentence 997.
# Inserted successfully for sentence 998.
# Inserted successfully for sentence 999.

# %%
start_time = 4:33pm
end_time = 5:17pm

# %%
query = """
    SELECT *
    FROM intern-project-415606.Criminal_Dataset.criminal_data_ner
    WHERE self_label = 'M' or self_label = 'N'
"""
# Run the query and get the result
query_job = client.query(query)

# Convert the result into a Pandas DataFrame
query_result = query_job.to_dataframe()

# Print the first few rows of the DataFrame
query_result.head(n=20)
# Out:
#    extract_id          text ner_underthesea tag_underthesea self_label
# 0           0  Nguyễn Văn C           B-PER              Np          N
# 1           0    25/01/1994               O               N          M
# 2           0            12           I-LOC               M          M
# 3           1   Trần Ngọc T           B-PER              Np          N
# 4           1    08/12/1993           I-LOC               M          M
# 5           1            x1               O               M          M
# 6           1     28/7/2021           I-LOC               M          M
# 7           2     Bùi Văn T           B-PER              Np          N
# 8           2    09/12/1989           I-LOC               M          M
# 9           2          1964           I-LOC               M          M
# 10          2          1966           I-LOC               M          M
# 11          2          1991           I-LOC               M          M
# 12          2          2014           I-LOC               M          M
# 13          2    07/05/2018           I-LOC               M          M
# 14          3  Nguyễn Văn Đ           B-PER              Np          N
# 15          3     04/8/1978           I-LOC               M          M
# 16          3          1949           I-LOC               M          M
# 17          3          1950           I-LOC               M          M
# 18          3          1984           I-LOC               M          M
# 19          3          2005               O               M          M
